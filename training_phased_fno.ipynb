# %%
import torch 
import meep as mp
import os
import numpy as np
import matplotlib.pyplot as plt
import torch.nn.functional as F
from torch import nn
from tqdm import tqdm
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision.io import read_image

print("Cuda Device Available:", torch.cuda.is_available())
print("Device Count:", torch.cuda.device_count())
print("Device Current:", torch.cuda.current_device())
# Out:
# Cuda Device Available: True
# Device Count: 1
# Device Current: 0

# %% [markdown]
# ### Utilities

# %%
class SpectralConv2d(nn.Module):
    """2D Fourier layer. It does FFT, linear transform, and Inverse FFT.    
    """
    def __init__(self, in_channels, out_channels, modes1, modes2):
        super(SpectralConv2d, self).__init__()
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.modes1 = modes1 
        self.modes2 = modes2

        self.scale = (1 / (in_channels * out_channels))
        self.weights1 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes1, self.modes2, dtype=torch.cfloat))
        self.weights2 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes1, self.modes2, dtype=torch.cfloat))

    def compl_mul2d(self, input, weights):
        return torch.einsum("bixy,ioxy->boxy", input, weights)

    def forward(self, x):
        batchsize = x.shape[0]
        x_ft = torch.fft.rfft2(x)

        out_ft = torch.zeros(batchsize, self.out_channels,  x.size(-2), x.size(-1)//2 + 1, dtype=torch.cfloat, device=x.device)
        out_ft[:, :, :self.modes1, :self.modes2] = \
            self.compl_mul2d(x_ft[:, :, :self.modes1, :self.modes2], self.weights1)
        out_ft[:, :, -self.modes1:, :self.modes2] = \
            self.compl_mul2d(x_ft[:, :, -self.modes1:, :self.modes2], self.weights2)

        x = torch.fft.irfft2(out_ft, s=(x.size(-2), x.size(-1)))
        return x
    
class MLP(nn.Module):
    def __init__(self, in_channels, out_channels, mid_channels):
        super(MLP, self).__init__()
        self.mlp1 = nn.Conv2d(in_channels, mid_channels, 1)
        self.mlp2 = nn.Conv2d(mid_channels, out_channels, 1)

    def forward(self, x):
        x = self.mlp1(x)
        x = F.gelu(x)
        x = self.mlp2(x)
        return x

# %%
class LpLoss(object):
    def __init__(self, d=2, p=2, size_average=True, reduction=True):
        super(LpLoss, self).__init__()

        #Dimension and Lp-norm type are postive
        assert d > 0 and p > 0

        self.d = d
        self.p = p
        self.reduction = reduction
        self.size_average = size_average

    def abs(self, x, y):
        num_examples = x.size()[0]

        #Assume uniform mesh
        h = 1.0 / (x.size()[1] - 1.0)

        all_norms = (h**(self.d/self.p))*torch.norm(x.view(num_examples,-1) - y.view(num_examples,-1), self.p, 1)

        if self.reduction:
            if self.size_average:
                return torch.mean(all_norms)
            else:
                return torch.sum(all_norms)

        return all_norms

    def rel(self, x, y):
        num_examples = x.size()[0]

        diff_norms = torch.norm(x.reshape(num_examples,-1) - y.reshape(num_examples,-1), self.p, 1)
        y_norms = torch.norm(y.reshape(num_examples,-1), self.p, 1)

        if self.reduction:
            if self.size_average:
                return torch.mean(diff_norms/y_norms)
            else:
                return torch.sum(diff_norms/y_norms)

        return diff_norms/y_norms

    def __call__(self, x, y):
        return self.rel(x, y)

# %%
class AntennaImageDataset(Dataset): 
    def __init__(self, folder_path): 
        self.label_path = os.path.join(folder_path, 'labels')
        self.input_path = os.path.join(folder_path, 'x')
        self.len = None
        
    def __len__(self): 
        if self.len == None: 
            self.len = 0
            for name in os.listdir(self.label_path):
                if ".png" in name: 
                    self.len += 1
        return self.len
        
    def __getitem__(self, idx): 
        input_path = os.path.join(self.input_path, 'train_%04d.png' % idx)
        label_path = os.path.join(self.label_path, 'train_%04d_label.png' % idx)
        
        input_img = read_image(input_path).to(dtype=torch.float32) / 255
        label_img = read_image(label_path).to(dtype=torch.float32) / 255
        
        return input_img, label_img

# %%
datasets = AntennaImageDataset('./data')
demo_input, demo_label = datasets[10]

fig, axes = plt.subplots(1, 2)
axes[0].imshow(demo_input.permute(1, 2, 0))
axes[1].imshow(demo_label.permute(1, 2, 0))

# %%
train_datasets, test_datasets = random_split(datasets, [0.8, 0.2])
train_dataloader = DataLoader(train_datasets, batch_size=32, shuffle=True)
test_dataloader = DataLoader(test_datasets, batch_size=32, shuffle=True)

# %%
class FNO2d(nn.Module): 
    def __init__(self, modes1, modes2, width): 
        super().__init__()
        self.modes1 = modes1
        self.modes2 = modes2
        self.width = width
        self.padding = 9
        
        self.p = nn.Linear(3, self.width)
        self.conv0 = SpectralConv2d(self.width, self.width, self.modes1, self.modes2)
        self.conv1 = SpectralConv2d(self.width, self.width, self.modes1, self.modes2)
        self.conv2 = SpectralConv2d(self.width, self.width, self.modes1, self.modes2)
        self.conv3 = SpectralConv2d(self.width, self.width, self.modes1, self.modes2)
        self.mlp0 = MLP(self.width, self.width, self.width)
        self.mlp1 = MLP(self.width, self.width, self.width)
        self.mlp2 = MLP(self.width, self.width, self.width)
        self.mlp3 = MLP(self.width, self.width, self.width)
        self.w0 = nn.Conv2d(self.width, self.width, 1)
        self.w1 = nn.Conv2d(self.width, self.width, 1)
        self.w2 = nn.Conv2d(self.width, self.width, 1)
        self.w3 = nn.Conv2d(self.width, self.width, 1)
        self.q = MLP(self.width, 1, self.width * 4)
        
    def forward(self, x):
        grid = self.get_grid(x.shape, x.device)
        x = torch.cat((x, grid), dim=1)
        x = self.p(x.permute(0, 2, 3, 1))
        x = x.permute(0, 3, 1, 2)
        x = F.pad(x, [0,self.padding, 0,self.padding])

        x1 = self.conv0(x)
        x1 = self.mlp0(x1)
        x2 = self.w0(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.conv1(x)
        x1 = self.mlp1(x1)
        x2 = self.w1(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.conv2(x)
        x1 = self.mlp2(x1)
        x2 = self.w2(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.conv3(x)
        x1 = self.mlp3(x1)
        x2 = self.w3(x)
        x = x1 + x2

        x = x[..., :-self.padding, :-self.padding]
        x = self.q(x)
        return x

    def get_grid(self, shape, device):
        batchsize, size_x, size_y = shape[0], shape[2], shape[3]
        gridx = torch.tensor(np.linspace(0, 1, size_x), dtype=torch.float)
        gridx = gridx.reshape(1, 1, size_x, 1).repeat([batchsize, 1, 1, size_y])
        gridy = torch.tensor(np.linspace(0, 1, size_y), dtype=torch.float)
        gridy = gridy.reshape(1, 1, 1, size_y).repeat([batchsize, 1, size_x, 1])
        return torch.cat((gridx, gridy), dim=1).to(device)

# %%
model = FNO2d(32, 32, 64) 
loss_func = LpLoss(size_average=False)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-2)

train_plot = []
test_plot = []

pbar = range(1000)
for epoch in pbar: 
    print("Beginning Epoch %d" % epoch)
    model.train()
    train_loss = 0
    test_loss = 0
    
    for i, (x, label) in enumerate(iter(train_dataloader)):
        print("  optimizing batch %d" % i)
        
        bsz = x.shape[0]
        optimizer.zero_grad()
        output = model(x)
        loss = loss_func(output.view(bsz, -1),
                          label.view(bsz, -1))
        loss.backward()
        optimizer.step()
        
        print("    loss = %f" % loss.item())
        train_loss += loss.item()
    
    model.eval()
    with torch.no_grad(): 
        for x, label in iter(test_dataloader): 
            bsz = x.shape[0]
            output = model(x)
            loss = loss_func(output.view(bsz, -1),
                              label.view(bsz, -1))
            test_loss += loss.item()
        
    # pbar.set_postfix({"train_loss": train_loss, 
    #                   "test_loss": test_loss})
    
    print("===\nEpoch %d Results: " % epoch)
    print("  train_loss = %f" % train_loss)
    print("  test_loss = %f" % test_loss)
    
    train_plot.append(train_loss)
    test_plot.append(test_loss)
# Out:
# Beginning Epoch 0
#   optimizing batch 0
#     loss = 27.969021
#   optimizing batch 1
#     loss = 33.712822
#   optimizing batch 2
#     loss = 22.552387
#   optimizing batch 3
#     loss = 20.647734
#   optimizing batch 4
#     loss = 19.875811
#   optimizing batch 5
#     loss = 19.030844
#   optimizing batch 6
#     loss = 20.582521
#   optimizing batch 7
#     loss = 22.070118
#   optimizing batch 8
#     loss = 21.513411
#   optimizing batch 9
#     loss = 20.677086
#   optimizing batch 10
#     loss = 10.093281
# ===
# Epoch 0 Results:
#   train_loss = 238.725035
#   test_loss = 51.298786
# Beginning Epoch 1
#   optimizing batch 0
#     loss = 19.271246
#   optimizing batch 1
#     loss = 18.051876
#   optimizing batch 2
#     loss = 17.740082
#   optimizing batch 3
#     loss = 17.219385
#   optimizing batch 4
#     loss = 16.718529
#   optimizing batch 5
#     loss = 17.190046
#   optimizing batch 6
#     loss = 17.458103
#   optimizing batch 7
#     loss = 16.495523
#   optimizing batch 8
#     loss = 16.160934
#   optimizing batch 9
#     loss = 16.009195
#   optimizing batch 10
#     loss = 8.110333
# ===
# Epoch 1 Results:
#   train_loss = 180.425254
#   test_loss = 44.768826
# Beginning Epoch 2
#   optimizing batch 0
#     loss = 15.998403
#   optimizing batch 1
#     loss = 16.365585
#   optimizing batch 2
#     loss = 16.214437
#   optimizing batch 3
#     loss = 16.916729
#   optimizing batch 4
#     loss = 16.427422
#   optimizing batch 5
#     loss = 17.007992
#   optimizing batch 6
#     loss = 15.950469
#   optimizing batch 7
#     loss = 16.415714
#   optimizing batch 8
#     loss = 16.630619
#   optimizing batch 9
#     loss = 16.725485
#   optimizing batch 10
#     loss = 7.755848
# ===
# Epoch 2 Results:
#   train_loss = 172.408703
#   test_loss = 44.257299
# Beginning Epoch 3
#   optimizing batch 0
#     loss = 15.510275
#   optimizing batch 1
#     loss = 16.468241
#   optimizing batch 2
#     loss = 16.529850
#   optimizing batch 3
#     loss = 15.813356
#   optimizing batch 4
#     loss = 16.137421
#   optimizing batch 5
#     loss = 16.655493
#   optimizing batch 6
#     loss = 16.870230
#   optimizing batch 7
#     loss = 16.537935
#   optimizing batch 8
#     loss = 15.654455
#   optimizing batch 9
#     loss = 17.057480
#   optimizing batch 10
#     loss = 8.536307
# ===
# Epoch 3 Results:
#   train_loss = 171.771043
#   test_loss = 46.730982
# Beginning Epoch 4
#   optimizing batch 0
#     loss = 17.267092
#   optimizing batch 1
#     loss = 16.831833
#   optimizing batch 2
#     loss = 15.983220
#   optimizing batch 3
#     loss = 18.310659
#   optimizing batch 4
#     loss = 16.232885
#   optimizing batch 5
#     loss = 16.610268
#   optimizing batch 6
#     loss = 16.209282
#   optimizing batch 7
#     loss = 15.993071
#   optimizing batch 8
#     loss = 15.809931
#   optimizing batch 9
#     loss = 15.747325
#   optimizing batch 10
#     loss = 8.029781
# ===
# Epoch 4 Results:
#   train_loss = 173.025347
#   test_loss = 43.141573
# Beginning Epoch 5
#   optimizing batch 0
#     loss = 15.854282
#   optimizing batch 1
#     loss = 16.056377
#   optimizing batch 2
#     loss = 16.119646
#   optimizing batch 3
#     loss = 16.325378
#   optimizing batch 4
#     loss = 16.405626
#   optimizing batch 5
#     loss = 15.789505
#   optimizing batch 6
#     loss = 16.059795
#   optimizing batch 7
#     loss = 15.405020
#   optimizing batch 8
#     loss = 16.538034
#   optimizing batch 9
#     loss = 15.911043
#   optimizing batch 10
#     loss = 8.111424
# ===
# Epoch 5 Results:
#   train_loss = 168.576133
#   test_loss = 43.361306
# Beginning Epoch 6
#   optimizing batch 0
#     loss = 15.813165
#   optimizing batch 1
#     loss = 15.882957
#   optimizing batch 2
#     loss = 15.705353
#   optimizing batch 3
#     loss = 16.987200
#   optimizing batch 4
#     loss = 15.613576
#   optimizing batch 5
#     loss = 16.345160
#   optimizing batch 6
#     loss = 15.833565
#   optimizing batch 7
#     loss = 16.057247
#   optimizing batch 8
#     loss = 16.276999
#   optimizing batch 9
#     loss = 16.108206
#   optimizing batch 10
#     loss = 7.816347
# ===
# Epoch 6 Results:
#   train_loss = 168.439773
#   test_loss = 43.310046
# Beginning Epoch 7
#   optimizing batch 0
#     loss = 16.109140
#   optimizing batch 1
#     loss = 16.102652
#   optimizing batch 2
#     loss = 16.112968
#   optimizing batch 3
#     loss = 15.394698
#   optimizing batch 4
#     loss = 16.003252
#   optimizing batch 5
#     loss = 15.433585
#   optimizing batch 6
#     loss = 16.255644
#   optimizing batch 7
#     loss = 16.390924
#   optimizing batch 8
#     loss = 15.932145
#   optimizing batch 9
#     loss = 15.980654
#   optimizing batch 10
#     loss = 7.946502
# ===
# Epoch 7 Results:
#   train_loss = 167.662165
#   test_loss = 43.485662
# Beginning Epoch 8
#   optimizing batch 0
#     loss = 16.165550
#   optimizing batch 1
#     loss = 16.062195
#   optimizing batch 2
#     loss = 16.049782
#   optimizing batch 3
#     loss = 16.009235
#   optimizing batch 4
#     loss = 15.965361
#   optimizing batch 5
#     loss = 15.706808
#   optimizing batch 6
#     loss = 15.807892
#   optimizing batch 7
#     loss = 15.988975
#   optimizing batch 8
#     loss = 16.545748
#   optimizing batch 9
#     loss = 16.055542
#   optimizing batch 10
#     loss = 8.011337
# ===
# Epoch 8 Results:
#   train_loss = 168.368424
#   test_loss = 43.906872
# Beginning Epoch 9
#   optimizing batch 0
#     loss = 16.488708
#   optimizing batch 1
#     loss = 15.834719
#   optimizing batch 2
#     loss = 15.741634
#   optimizing batch 3
#     loss = 15.523430
#   optimizing batch 4
#     loss = 15.837352
#   optimizing batch 5
#     loss = 15.802538
#   optimizing batch 6
#     loss = 15.634332
#   optimizing batch 7
#     loss = 15.892881
#   optimizing batch 8
#     loss = 15.618431
#   optimizing batch 9
#     loss = 16.236128
#   optimizing batch 10
#     loss = 9.270674
# ===
# Epoch 9 Results:
#   train_loss = 167.880827
#   test_loss = 49.020811
# Beginning Epoch 10
#   optimizing batch 0
#     loss = 18.496208
#   optimizing batch 1
#     loss = 17.596285
#   optimizing batch 2
#     loss = 16.653614
#   optimizing batch 3
#     loss = 19.782980
#   optimizing batch 4
#     loss = 16.467674
#   optimizing batch 5
#     loss = 17.238651
#   optimizing batch 6
#     loss = 17.961580
#   optimizing batch 7
#     loss = 16.975065
#   optimizing batch 8
#     loss = 16.733524
#   optimizing batch 9
#     loss = 18.749348
#   optimizing batch 10
#     loss = 8.130326
# ===
# Epoch 10 Results:
#   train_loss = 184.785256
#   test_loss = 46.235363
# Beginning Epoch 11
#   optimizing batch 0
#     loss = 17.342754
#   optimizing batch 1
#     loss = 17.793385
#   optimizing batch 2
#     loss = 16.395100
#   optimizing batch 3
#     loss = 16.536674
#   optimizing batch 4
#     loss = 16.089317
#   optimizing batch 5
#     loss = 16.366041
#   optimizing batch 6
#     loss = 16.417656
#   optimizing batch 7
#     loss = 16.309296
#   optimizing batch 8
#     loss = 15.940318
#   optimizing batch 9
#     loss = 16.430279
#   optimizing batch 10
#     loss = 8.233755
# ===
# Epoch 11 Results:
#   train_loss = 173.854575
#   test_loss = 43.758679
# Beginning Epoch 12
#   optimizing batch 0
#     loss = 16.200741
#   optimizing batch 1
#     loss = 16.205246
#   optimizing batch 2
#     loss = 15.851665
#   optimizing batch 3
#     loss = 16.564613
#   optimizing batch 4
#     loss = 15.885642
#   optimizing batch 5
#     loss = 16.029329
#   optimizing batch 6
#     loss = 16.076918
#   optimizing batch 7
#     loss = 16.046890
#   optimizing batch 8
#     loss = 16.476086
#   optimizing batch 9
#     loss = 16.064886
#   optimizing batch 10
#     loss = 7.847836
# ===
# Epoch 12 Results:
#   train_loss = 169.249853
#   test_loss = 43.827905
# Beginning Epoch 13
#   optimizing batch 0
#     loss = 15.800809
#   optimizing batch 1
#     loss = 16.069508
#   optimizing batch 2
#     loss = 16.562199
#   optimizing batch 3
#     loss = 16.095432
#   optimizing batch 4
#     loss = 16.868057
#   optimizing batch 5
#     loss = 16.174347
#   optimizing batch 6
#     loss = 16.001474
#   optimizing batch 7
#     loss = 15.933036
#   optimizing batch 8
#     loss = 16.061840
#   optimizing batch 9
#     loss = 15.722530
#   optimizing batch 10
#     loss = 7.939975
# ===
# Epoch 13 Results:
#   train_loss = 169.229208
#   test_loss = 43.446069
# Beginning Epoch 14
#   optimizing batch 0
#     loss = 15.718513
#   optimizing batch 1
#     loss = 15.443844
#   optimizing batch 2
#     loss = 16.019192
#   optimizing batch 3
#     loss = 16.295630
#   optimizing batch 4
#     loss = 15.692040
#   optimizing batch 5
#     loss = 15.996601
#   optimizing batch 6
#     loss = 16.641270
#   optimizing batch 7
#     loss = 15.804201
#   optimizing batch 8
#     loss = 15.819166
#   optimizing batch 9
#     loss = 15.770954
#   optimizing batch 10
#     loss = 8.266763
# ===
# Epoch 14 Results:
#   train_loss = 167.468173
#   test_loss = 43.249698
# Beginning Epoch 15
#   optimizing batch 0
#     loss = 16.679409
#   optimizing batch 1
#     loss = 15.746246
#   optimizing batch 2
#     loss = 15.897534
#   optimizing batch 3
#     loss = 16.107332
#   optimizing batch 4
#     loss = 16.148781
#   optimizing batch 5
#     loss = 15.653051
#   optimizing batch 6
#     loss = 15.657239
#   optimizing batch 7
#     loss = 15.960259
#   optimizing batch 8
#     loss = 15.939978
#   optimizing batch 9
#     loss = 15.466009
#   optimizing batch 10
#     loss = 8.030133
# ===
# Epoch 15 Results:
#   train_loss = 167.285973
#   test_loss = 43.330440
# Beginning Epoch 16
#   optimizing batch 0
#     loss = 16.216356
#   optimizing batch 1
#     loss = 15.571040
#   optimizing batch 2
#     loss = 16.017559
#   optimizing batch 3
#     loss = 16.005306
#   optimizing batch 4
#     loss = 16.073957
#   optimizing batch 5
#     loss = 16.110567
#   optimizing batch 6
#     loss = 15.757215
#   optimizing batch 7
#     loss = 16.034288
#   optimizing batch 8
#     loss = 15.760592
#   optimizing batch 9
#     loss = 15.880374
#   optimizing batch 10
#     loss = 7.712917
# ===
# Epoch 16 Results:
#   train_loss = 167.140172
#   test_loss = 41.627501
# Beginning Epoch 17
#   optimizing batch 0
#     loss = 15.500463
#   optimizing batch 1
#     loss = 14.833620
#   optimizing batch 2
#     loss = 15.142801
#   optimizing batch 3
#     loss = 15.248717
#   optimizing batch 4
#     loss = 16.012161
#   optimizing batch 5
#     loss = 15.773830
#   optimizing batch 6
#     loss = 14.968576
#   optimizing batch 7
#     loss = 15.290443
#   optimizing batch 8
#     loss = 15.862389
#   optimizing batch 9
#     loss = 14.593547
#   optimizing batch 10
#     loss = 7.005175
# ===
# Epoch 17 Results:
#   train_loss = 160.231723
#   test_loss = 41.253489
# Beginning Epoch 18
#   optimizing batch 0
#     loss = 15.400177
#   optimizing batch 1
#     loss = 15.084491
#   optimizing batch 2
#     loss = 16.268011
#   optimizing batch 3
#     loss = 14.516027
#   optimizing batch 4
#     loss = 14.642727
#   optimizing batch 5
#     loss = 14.676098
#   optimizing batch 6
#     loss = 15.276302
#   optimizing batch 7
#     loss = 14.755122
#   optimizing batch 8
#     loss = 14.867992
#   optimizing batch 9
#     loss = 14.467053
#   optimizing batch 10
#     loss = 7.199377
# ===
# Epoch 18 Results:
#   train_loss = 157.153378
#   test_loss = 38.627982
# Beginning Epoch 19
#   optimizing batch 0
#     loss = 14.471800
#   optimizing batch 1
#     loss = 14.447622
#   optimizing batch 2
#     loss = 14.666039
#   optimizing batch 3
#     loss = 13.971324
#   optimizing batch 4
#     loss = 14.835827
#   optimizing batch 5
#     loss = 13.657395
#   optimizing batch 6
#     loss = 14.633142
#   optimizing batch 7
#     loss = 14.416443
#   optimizing batch 8
#     loss = 13.993373
#   optimizing batch 9
#     loss = 14.292297
#   optimizing batch 10
#     loss = 6.830173
# ===
# Epoch 19 Results:
#   train_loss = 150.215435
#   test_loss = 36.959607
# Beginning Epoch 20
#   optimizing batch 0
#     loss = 13.561768
#   optimizing batch 1
#     loss = 13.139684
#   optimizing batch 2
#     loss = 13.406051
#   optimizing batch 3
#     loss = 13.232655
#   optimizing batch 4
#     loss = 12.982099
#   optimizing batch 5
#     loss = 12.851763
#   optimizing batch 6
#     loss = 12.582680
#   optimizing batch 7
#     loss = 12.705971
#   optimizing batch 8
#     loss = 12.569689
#   optimizing batch 9
#     loss = 12.119705
#   optimizing batch 10
#     loss = 6.523999
# ===
# Epoch 20 Results:
#   train_loss = 135.676061
#   test_loss = 31.120248
# Beginning Epoch 21
#   optimizing batch 0
#     loss = 11.049103
#   optimizing batch 1
#     loss = 11.838643
#   optimizing batch 2
#     loss = 14.790029
#   optimizing batch 3
#     loss = 13.979550
#   optimizing batch 4
#     loss = 14.415324
#   optimizing batch 5
#     loss = 12.773698
#   optimizing batch 6
#     loss = 13.637515
#   optimizing batch 7
#     loss = 11.660775
#   optimizing batch 8
#     loss = 11.605656
#   optimizing batch 9
#     loss = 10.455089
#   optimizing batch 10
#     loss = 4.979130
# ===
# Epoch 21 Results:
#   train_loss = 131.184511
#   test_loss = 26.395857
# Beginning Epoch 22
#   optimizing batch 0
#     loss = 9.465638
#   optimizing batch 1
#     loss = 10.305307
#   optimizing batch 2
#     loss = 20.589800
#   optimizing batch 3
#     loss = 15.886738
#   optimizing batch 4
#     loss = 14.467868
#   optimizing batch 5
#     loss = 13.465261
#   optimizing batch 6
#     loss = 12.731769
#   optimizing batch 7
#     loss = 11.568690
#   optimizing batch 8
#     loss = 10.843950
#   optimizing batch 9
#     loss = 13.092476
#   optimizing batch 10
#     loss = 8.873935
# ===
# Epoch 22 Results:
#   train_loss = 141.291431
#   test_loss = 35.275050
# Beginning Epoch 23
#   optimizing batch 0
#     loss = 12.827473
#   optimizing batch 1
#     loss = 17.461855
#   optimizing batch 2
#     loss = 16.644930
#   optimizing batch 3
#     loss = 11.679467
#   optimizing batch 4
#     loss = 14.498737
#   optimizing batch 5
#     loss = 11.576055
#   optimizing batch 6
#     loss = 11.633106
#   optimizing batch 7
#     loss = 14.689223
#   optimizing batch 8
#     loss = 10.368278
#   optimizing batch 9
#     loss = 10.146519
#   optimizing batch 10
#     loss = 5.410195
# ===
# Epoch 23 Results:
#   train_loss = 136.935837
#   test_loss = 28.977009
# Beginning Epoch 24
#   optimizing batch 0
#     loss = 10.779331
#   optimizing batch 1
#     loss = 15.143286
#   optimizing batch 2
#     loss = 10.294199
#   optimizing batch 3
#     loss = 25.764294
#   optimizing batch 4
#     loss = 9.912755
#   optimizing batch 5
#     loss = 13.264771
#   optimizing batch 6
#     loss = 12.814549
#   optimizing batch 7
#     loss = 10.460842
#   optimizing batch 8
#     loss = 11.786700
#   optimizing batch 9
#     loss = 10.469053
#   optimizing batch 10
#     loss = 6.799392
# ===
# Epoch 24 Results:
#   train_loss = 137.489173
#   test_loss = 42.175927
# Beginning Epoch 25
#   optimizing batch 0
#     loss = 14.993317
#   optimizing batch 1
#     loss = 10.671110
#   optimizing batch 2
#     loss = 10.673224
#   optimizing batch 3
#     loss = 12.280830
#   optimizing batch 4
#     loss = 8.731209
#   optimizing batch 5
#     loss = 11.469206
#   optimizing batch 6
#     loss = 10.258528
#   optimizing batch 7
#     loss = 9.199941
#   optimizing batch 8
#     loss = 10.622372
#   optimizing batch 9
#     loss = 9.032079
#   optimizing batch 10
#     loss = 4.983310
# ===
# Epoch 25 Results:
#   train_loss = 112.915125
#   test_loss = 24.575626
# Beginning Epoch 26
#   optimizing batch 0
#     loss = 8.798020
#   optimizing batch 1
#     loss = 9.653304
#   optimizing batch 2
#     loss = 6.888251
#   optimizing batch 3
#     loss = 8.876378
#   optimizing batch 4
#     loss = 7.385249
#   optimizing batch 5
#     loss = 8.609717
#   optimizing batch 6
#     loss = 6.333100
#   optimizing batch 7
#     loss = 8.200441
#   optimizing batch 8
#     loss = 7.165134
#   optimizing batch 9
#     loss = 8.684271
#   optimizing batch 10
#     loss = 2.899036
# ===
# Epoch 26 Results:
#   train_loss = 83.492902
#   test_loss = 21.330969
# Beginning Epoch 27
#   optimizing batch 0
#     loss = 7.565655
#   optimizing batch 1
#     loss = 6.020154
#   optimizing batch 2
#     loss = 7.086744
#   optimizing batch 3
#     loss = 5.578885
#   optimizing batch 4
#     loss = 6.369667
#   optimizing batch 5
#     loss = 5.167428
#   optimizing batch 6
#     loss = 6.101432
#   optimizing batch 7
#     loss = 5.934883
#   optimizing batch 8
#     loss = 4.967169
#   optimizing batch 9
#     loss = 5.710409
#   optimizing batch 10
#     loss = 2.489381
# ===
# Epoch 27 Results:
#   train_loss = 62.991808
#   test_loss = 18.632418
# Beginning Epoch 28
#   optimizing batch 0
#     loss = 6.144754
#   optimizing batch 1
#     loss = 5.572834
#   optimizing batch 2
#     loss = 4.440271
#   optimizing batch 3
#     loss = 5.226740
#   optimizing batch 4
#     loss = 4.893233
#   optimizing batch 5
#     loss = 4.332979
#   optimizing batch 6
#     loss = 4.287646
#   optimizing batch 7
#     loss = 4.561111
#   optimizing batch 8
#     loss = 5.370075
#   optimizing batch 9
#     loss = 4.334480
#   optimizing batch 10
#     loss = 2.686126
# ===
# Epoch 28 Results:
#   train_loss = 51.850251
#   test_loss = 13.605482
# Beginning Epoch 29
#   optimizing batch 0
#     loss = 4.058696
#   optimizing batch 1
#     loss = 4.047308
#   optimizing batch 2
#     loss = 3.975037
#   optimizing batch 3
#     loss = 4.664912
#   optimizing batch 4
#     loss = 4.031884
#   optimizing batch 5
#     loss = 3.638211
#   optimizing batch 6
#     loss = 4.115430
#   optimizing batch 7
#     loss = 4.176681
#   optimizing batch 8
#     loss = 3.650394
#   optimizing batch 9
#     loss = 3.534436
#   optimizing batch 10
#     loss = 1.910261
# ===
# Epoch 29 Results:
#   train_loss = 41.803249
#   test_loss = 12.243345
# Beginning Epoch 30
#   optimizing batch 0
#     loss = 3.362516
#   optimizing batch 1
#     loss = 3.638497
#   optimizing batch 2
#     loss = 4.119658
#   optimizing batch 3
#     loss = 5.280931
#   optimizing batch 4
#     loss = 3.295684
#   optimizing batch 5
#     loss = 6.471146
#   optimizing batch 6
#     loss = 4.596408
#   optimizing batch 7
#     loss = 4.042844
#   optimizing batch 8
#     loss = 5.764060
#   optimizing batch 9
#     loss = 3.415761
#   optimizing batch 10
#     loss = 2.572636
# ===
# Epoch 30 Results:
#   train_loss = 46.560140
#   test_loss = 15.593369
# Beginning Epoch 31
#   optimizing batch 0
#     loss = 4.820404
#   optimizing batch 1
#     loss = 5.638366
#   optimizing batch 2
#     loss = 3.861020
#   optimizing batch 3
#     loss = 6.582830
#   optimizing batch 4
#     loss = 5.502304
#   optimizing batch 5
#     loss = 5.869317
#   optimizing batch 6
#     loss = 4.586132
#   optimizing batch 7
#     loss = 5.209216
#   optimizing batch 8
#     loss = 5.144649
#   optimizing batch 9
#     loss = 4.977459
#   optimizing batch 10
#     loss = 2.243811
# ===
# Epoch 31 Results:
#   train_loss = 54.435508
#   test_loss = 13.317961
# Beginning Epoch 32
#   optimizing batch 0
#     loss = 3.447135
#   optimizing batch 1
#     loss = 3.920133
#   optimizing batch 2
#     loss = 4.289322
#   optimizing batch 3
#     loss = 3.330087
#   optimizing batch 4
#     loss = 4.312116
#   optimizing batch 5
#     loss = 3.312116
#   optimizing batch 6
#     loss = 4.262196
#   optimizing batch 7
#     loss = 3.763943
#   optimizing batch 8
#     loss = 3.441793
#   optimizing batch 9
#     loss = 4.670014
#   optimizing batch 10
#     loss = 1.585550
# ===
# Epoch 32 Results:
#   train_loss = 40.334405
#   test_loss = 14.129015
# Beginning Epoch 33
#   optimizing batch 0
#     loss = 4.202678
#   optimizing batch 1
#     loss = 3.752763
#   optimizing batch 2
#     loss = 3.111596
#   optimizing batch 3
#     loss = 4.016164
#   optimizing batch 4
#     loss = 3.047922
#   optimizing batch 5
#     loss = 3.904309
#   optimizing batch 6
#     loss = 3.418582
#   optimizing batch 7
#     loss = 3.087805
#   optimizing batch 8
#     loss = 4.324873
#   optimizing batch 9
#     loss = 3.193311
#   optimizing batch 10
#     loss = 1.467716
# ===
# Epoch 33 Results:
#   train_loss = 37.527719
#   test_loss = 12.430319
# Beginning Epoch 34
#   optimizing batch 0
#     loss = 3.154169
#   optimizing batch 1
#     loss = 2.771352
#   optimizing batch 2
#     loss = 2.819303
#   optimizing batch 3
#     loss = 2.824822
#   optimizing batch 4
#     loss = 2.608874
#   optimizing batch 5
#     loss = 2.594451
#   optimizing batch 6
#     loss = 2.843879
#   optimizing batch 7
#     loss = 3.365852
#   optimizing batch 8
#     loss = 2.980346
#   optimizing batch 9
#     loss = 2.680409
#   optimizing batch 10
#     loss = 1.354133
# ===
# Epoch 34 Results:
#   train_loss = 29.997589
#   test_loss = 11.330028
# Beginning Epoch 35
#   optimizing batch 0
#     loss = 2.602308
#   optimizing batch 1
#     loss = 3.177786
#   optimizing batch 2
#     loss = 3.160228
#   optimizing batch 3
#     loss = 2.669658
#   optimizing batch 4
#     loss = 2.814061
#   optimizing batch 5
#     loss = 3.457822
#   optimizing batch 6
#     loss = 3.443106
#   optimizing batch 7
#     loss = 2.457487
#   optimizing batch 8
#     loss = 3.046166
#   optimizing batch 9
#     loss = 3.246384
#   optimizing batch 10
#     loss = 1.322835
# ===
# Epoch 35 Results:
#   train_loss = 31.397842
#   test_loss = 12.792932
# Beginning Epoch 36
#   optimizing batch 0
#     loss = 3.070358
#   optimizing batch 1
#     loss = 2.983509
#   optimizing batch 2
#     loss = 2.497766
#   optimizing batch 3
#     loss = 3.467113
#   optimizing batch 4
#     loss = 3.149326
#   optimizing batch 5
#     loss = 2.411435
#   optimizing batch 6
#     loss = 3.881748
#   optimizing batch 7
#     loss = 3.225398
#   optimizing batch 8
#     loss = 2.541397
#   optimizing batch 9
#     loss = 3.915675
#   optimizing batch 10
#     loss = 1.285048
# ===
# Epoch 36 Results:
#   train_loss = 32.428773
#   test_loss = 13.776008
# Beginning Epoch 37
#   optimizing batch 0
#     loss = 3.708018
#   optimizing batch 1
#     loss = 2.738822
#   optimizing batch 2
#     loss = 2.754538
#   optimizing batch 3
#     loss = 3.237688
#   optimizing batch 4
#     loss = 2.433142
#   optimizing batch 5
#     loss = 3.416641
#   optimizing batch 6
#     loss = 3.021054
#   optimizing batch 7
#     loss = 2.574214
#   optimizing batch 8
#     loss = 3.618619
#   optimizing batch 9
#     loss = 2.469410
#   optimizing batch 10
#     loss = 1.261507
# ===
# Epoch 37 Results:
#   train_loss = 31.233653
#   test_loss = 11.189390
# Beginning Epoch 38
#   optimizing batch 0
#     loss = 2.416158
#   optimizing batch 1
#     loss = 2.310468
#   optimizing batch 2
#     loss = 2.548904
#   optimizing batch 3
#     loss = 2.460953
#   optimizing batch 4
#     loss = 2.303437
#   optimizing batch 5
#     loss = 2.331465
#   optimizing batch 6
#     loss = 2.494850
#   optimizing batch 7
#     loss = 2.443046
#   optimizing batch 8
#     loss = 2.205358
#   optimizing batch 9
#     loss = 2.114629
#   optimizing batch 10
#     loss = 1.086848
# ===
# Epoch 38 Results:
#   train_loss = 24.716116
#   test_loss = 10.869155
# Beginning Epoch 39
#   optimizing batch 0
#     loss = 2.072888
#   optimizing batch 1
#     loss = 2.079516
#   optimizing batch 2
#     loss = 2.142859
#   optimizing batch 3
#     loss = 2.276481
#   optimizing batch 4
#     loss = 2.344380
#   optimizing batch 5
#     loss = 2.196200
#   optimizing batch 6
#     loss = 2.122563
#   optimizing batch 7
#     loss = 2.025810
#   optimizing batch 8
#     loss = 2.035557
#   optimizing batch 9
#     loss = 2.248927
#   optimizing batch 10
#     loss = 1.317611
# ===
# Epoch 39 Results:
#   train_loss = 22.862792
#   test_loss = 11.542699
# Beginning Epoch 40
#   optimizing batch 0
#     loss = 2.608669
#   optimizing batch 1
#     loss = 4.491084
#   optimizing batch 2
#     loss = 2.278975
#   optimizing batch 3
#     loss = 5.155068
#   optimizing batch 4
#     loss = 3.937250
#   optimizing batch 5
#     loss = 4.738070
#   optimizing batch 6
#     loss = 3.683065
#   optimizing batch 7
#     loss = 5.108829
#   optimizing batch 8
#     loss = 5.323273
#   optimizing batch 9
#     loss = 3.073085
#   optimizing batch 10
#     loss = 2.913285
# ===
# Epoch 40 Results:
#   train_loss = 43.310652
#   test_loss = 20.118216
# Beginning Epoch 41
#   optimizing batch 0
#     loss = 6.641355
#   optimizing batch 1
#     loss = 3.700572
#   optimizing batch 2
#     loss = 4.245232
#   optimizing batch 3
#     loss = 3.601859
#   optimizing batch 4
#     loss = 4.344343
#   optimizing batch 5
#     loss = 3.146510
#   optimizing batch 6
#     loss = 3.727601
#   optimizing batch 7
#     loss = 3.320084
#   optimizing batch 8
#     loss = 4.068949
#   optimizing batch 9
#     loss = 3.581887
#   optimizing batch 10
#     loss = 1.450406
# ===
# Epoch 41 Results:
#   train_loss = 41.828798
#   test_loss = 12.533108
# Beginning Epoch 42
#   optimizing batch 0
#     loss = 3.058347
#   optimizing batch 1
#     loss = 2.802164
#   optimizing batch 2
#     loss = 3.125778
#   optimizing batch 3
#     loss = 2.533032
#   optimizing batch 4
#     loss = 2.607846
#   optimizing batch 5
#     loss = 2.926169
#   optimizing batch 6
#     loss = 2.664968
#   optimizing batch 7
#     loss = 2.223825
#   optimizing batch 8
#     loss = 2.706675
#   optimizing batch 9
#     loss = 2.618806
#   optimizing batch 10
#     loss = 1.198775
# ===
# Epoch 42 Results:
#   train_loss = 28.466386
#   test_loss = 11.652439
# Beginning Epoch 43
#   optimizing batch 0
#     loss = 2.553946
#   optimizing batch 1
#     loss = 2.596863
#   optimizing batch 2
#     loss = 2.286347
#   optimizing batch 3
#     loss = 2.144221
#   optimizing batch 4
#     loss = 2.980466
#   optimizing batch 5
#     loss = 2.818208
#   optimizing batch 6
#     loss = 2.111552
#   optimizing batch 7
#     loss = 2.256760
#   optimizing batch 8
#     loss = 2.605479
#   optimizing batch 9
#     loss = 2.080313
#   optimizing batch 10
#     loss = 1.145486
# ===
# Epoch 43 Results:
#   train_loss = 25.579642
#   test_loss = 10.878169
# Beginning Epoch 44
#   optimizing batch 0
#     loss = 2.091331
#   optimizing batch 1
#     loss = 1.904775
#   optimizing batch 2
#     loss = 2.042305
#   optimizing batch 3
#     loss = 2.619603
#   optimizing batch 4
#     loss = 2.189851
#   optimizing batch 5
#     loss = 1.920492
#   optimizing batch 6
#     loss = 1.886802
#   optimizing batch 7
#     loss = 2.295672
#   optimizing batch 8
#     loss = 2.649497
#   optimizing batch 9
#     loss = 2.018253
#   optimizing batch 10
#     loss = 0.973581
# ===
# Epoch 44 Results:
#   train_loss = 22.592162
#   test_loss = 10.641536
# Beginning Epoch 45
#   optimizing batch 0
#     loss = 1.884647
#   optimizing batch 1
#     loss = 1.781101
#   optimizing batch 2
#     loss = 1.793236
#   optimizing batch 3
#     loss = 2.118208
#   optimizing batch 4
#     loss = 2.083023
#   optimizing batch 5
#     loss = 1.940615
#   optimizing batch 6
#     loss = 1.848825
#   optimizing batch 7
#     loss = 1.973264
#   optimizing batch 8
#     loss = 2.128099
#   optimizing batch 9
#     loss = 2.181293
#   optimizing batch 10
#     loss = 0.913423
# ===
# Epoch 45 Results:
#   train_loss = 20.645734
#   test_loss = 10.961884
# Beginning Epoch 46
#   optimizing batch 0
#     loss = 2.178391
#   optimizing batch 1
#     loss = 3.265441
#   optimizing batch 2
#     loss = 1.806092
#   optimizing batch 3
#     loss = 3.187733
#   optimizing batch 4
#     loss = 2.145577
#   optimizing batch 5
#     loss = 2.070539
#   optimizing batch 6
#     loss = 2.606807
#   optimizing batch 7
#     loss = 2.072691
#   optimizing batch 8
#     loss = 1.817704
#   optimizing batch 9
#     loss = 2.400262
#   optimizing batch 10
#     loss = 1.171834
# ===
# Epoch 46 Results:
#   train_loss = 24.723071
#   test_loss = 11.987156
# Beginning Epoch 47
#   optimizing batch 0
#     loss = 2.853641
#   optimizing batch 1
#     loss = 3.306651
#   optimizing batch 2
#     loss = 1.910491
#   optimizing batch 3
#     loss = 2.933918
#   optimizing batch 4
#     loss = 1.963538
#   optimizing batch 5
#     loss = 2.186293
#   optimizing batch 6
#     loss = 2.379542
#   optimizing batch 7
#     loss = 1.892951
#   optimizing batch 8
#     loss = 2.410850
#   optimizing batch 9
#     loss = 3.026007
#   optimizing batch 10
#     loss = 0.929869
# ===
# Epoch 47 Results:
#   train_loss = 25.793751
#   test_loss = 12.012186
# Beginning Epoch 48
#   optimizing batch 0
#     loss = 2.838732
#   optimizing batch 1
#     loss = 2.022915
#   optimizing batch 2
#     loss = 1.945840
#   optimizing batch 3
#     loss = 2.727162
#   optimizing batch 4
#     loss = 2.072994
#   optimizing batch 5
#     loss = 1.890535
#   optimizing batch 6
#     loss = 2.858660
#   optimizing batch 7
#     loss = 2.149010
#   optimizing batch 8
#     loss = 1.793396
#   optimizing batch 9
#     loss = 2.554869
#   optimizing batch 10
#     loss = 1.039000
# ===
# Epoch 48 Results:
#   train_loss = 23.893112
#   test_loss = 11.720365
# Beginning Epoch 49
#   optimizing batch 0
#     loss = 2.504355
#   optimizing batch 1
#     loss = 2.480280
#   optimizing batch 2
#     loss = 1.768115
#   optimizing batch 3
#     loss = 2.856296
#   optimizing batch 4
#     loss = 1.827389
#   optimizing batch 5
#     loss = 2.306585
#   optimizing batch 6
#     loss = 2.202497
#   optimizing batch 7
#     loss = 1.830044
#   optimizing batch 8
#     loss = 2.638094
#   optimizing batch 9
#     loss = 2.023266
#   optimizing batch 10
#     loss = 0.948939
# ===
# Epoch 49 Results:
#   train_loss = 23.385860
#   test_loss = 10.972088
# Beginning Epoch 50
#   optimizing batch 0
#     loss = 2.260679
#   optimizing batch 1
#     loss = 2.315778
#   optimizing batch 2
#     loss = 1.748850
#   optimizing batch 3
#     loss = 2.026814
#   optimizing batch 4
#     loss = 1.802494
#   optimizing batch 5
#     loss = 1.745341
#   optimizing batch 6
#     loss = 2.152179
#   optimizing batch 7
#     loss = 2.045022
#   optimizing batch 8
#     loss = 1.791752
#   optimizing batch 9
#     loss = 2.194398
#   optimizing batch 10
#     loss = 1.176759
# ===
# Epoch 50 Results:
#   train_loss = 21.260064
#   test_loss = 11.835588
# Beginning Epoch 51
#   optimizing batch 0
#     loss = 2.608971
#   optimizing batch 1
#     loss = 2.670633
#   optimizing batch 2
#     loss = 1.752321
#   optimizing batch 3
#     loss = 2.679722
#   optimizing batch 4
#     loss = 1.790449
#   optimizing batch 5
#     loss = 2.710317
#   optimizing batch 6
#     loss = 2.438154
#   optimizing batch 7
#     loss = 1.776174
#   optimizing batch 8
#     loss = 2.393311
#   optimizing batch 9
#     loss = 2.078912
#   optimizing batch 10
#     loss = 0.973548
# ===
# Epoch 51 Results:
#   train_loss = 23.872513
#   test_loss = 10.637862
# Beginning Epoch 52
#   optimizing batch 0
#     loss = 1.764587
#   optimizing batch 1
#     loss = 1.800156
#   optimizing batch 2
#     loss = 1.916262
#   optimizing batch 3
#     loss = 1.861404
#   optimizing batch 4
#     loss = 1.762995
#   optimizing batch 5
#     loss = 2.033439
#   optimizing batch 6
#     loss = 1.797055
#   optimizing batch 7
#     loss = 2.035568
#   optimizing batch 8
#     loss = 2.181404
#   optimizing batch 9
#     loss = 1.665834
#   optimizing batch 10
#     loss = 0.961408
# ===
# Epoch 52 Results:
#   train_loss = 19.780112
#   test_loss = 10.630167
# Beginning Epoch 53
#   optimizing batch 0
#     loss = 1.755299
#   optimizing batch 1
#     loss = 2.028306
#   optimizing batch 2
#     loss = 2.073630
#   optimizing batch 3
#     loss = 2.096689
#   optimizing batch 4
#     loss = 1.698799
#   optimizing batch 5
#     loss = 2.464394
#   optimizing batch 6
#     loss = 2.106384
#   optimizing batch 7
#     loss = 1.840732
#   optimizing batch 8
#     loss = 1.827260
#   optimizing batch 9
#     loss = 1.987992
#   optimizing batch 10
#     loss = 0.884247
# ===
# Epoch 53 Results:
#   train_loss = 20.763731
#   test_loss = 10.966664
# Beginning Epoch 54
#   optimizing batch 0
#     loss = 2.029063
#   optimizing batch 1
#     loss = 2.941054
#   optimizing batch 2
#     loss = 1.931361
#   optimizing batch 3
#     loss = 3.557551
#   optimizing batch 4
#     loss = 2.147410
#   optimizing batch 5
#     loss = 3.556790
#   optimizing batch 6
#     loss = 2.362625
#   optimizing batch 7
#     loss = 4.391325
#   optimizing batch 8
#     loss = 2.703410
#   optimizing batch 9
#     loss = 4.490976
#   optimizing batch 10
#     loss = 1.872818
# ===
# Epoch 54 Results:
#   train_loss = 31.984382
#   test_loss = 11.936507
# Beginning Epoch 55
#   optimizing batch 0
#     loss = 2.563846
#   optimizing batch 1
#     loss = 3.890856
#   optimizing batch 2
#     loss = 3.331745
#   optimizing batch 3
#     loss = 2.612334
#   optimizing batch 4
#     loss = 3.498421
#   optimizing batch 5
#     loss = 2.729528
#   optimizing batch 6
#     loss = 3.864747
#   optimizing batch 7
#     loss = 3.297404
#   optimizing batch 8
#     loss = 3.241181
#   optimizing batch 9
#     loss = 2.464110
#   optimizing batch 10
#     loss = 1.497564
# ===
# Epoch 55 Results:
#   train_loss = 32.991737
#   test_loss = 13.388669
# Beginning Epoch 56
#   optimizing batch 0
#     loss = 3.352026
#   optimizing batch 1
#     loss = 2.825788
#   optimizing batch 2
#     loss = 2.720359
#   optimizing batch 3
#     loss = 3.139024
#   optimizing batch 4
#     loss = 2.556937
#   optimizing batch 5
#     loss = 3.466233
#   optimizing batch 6
#     loss = 2.641742
#   optimizing batch 7
#     loss = 3.851816
#   optimizing batch 8
#     loss = 3.424470
#   optimizing batch 9
#     loss = 3.273234
#   optimizing batch 10
#     loss = 1.233731
# ===
# Epoch 56 Results:
#   train_loss = 32.485360
#   test_loss = 11.763151
# Beginning Epoch 57
#   optimizing batch 0
#     loss = 2.522602
#   optimizing batch 1
#     loss = 2.627526
#   optimizing batch 2
#     loss = 2.714652
#   optimizing batch 3
#     loss = 2.220185
#   optimizing batch 4
#     loss = 2.341300
#   optimizing batch 5
#     loss = 2.151636
#   optimizing batch 6
#     loss = 1.994593
#   optimizing batch 7
#     loss = 2.062708
#   optimizing batch 8
#     loss = 2.290473
#   optimizing batch 9
#     loss = 2.100904
#   optimizing batch 10
#     loss = 1.044977
# ===
# Epoch 57 Results:
#   train_loss = 24.071554
#   test_loss = 10.699660
# Beginning Epoch 58
#   optimizing batch 0
#     loss = 1.820566
#   optimizing batch 1
#     loss = 1.817470
#   optimizing batch 2
#     loss = 1.877957
#   optimizing batch 3
#     loss = 1.801966
#   optimizing batch 4
#     loss = 1.887774
#   optimizing batch 5
#     loss = 2.501486
#   optimizing batch 6
#     loss = 1.972316
#   optimizing batch 7
#     loss = 1.621995
#   optimizing batch 8
#     loss = 2.120856
#   optimizing batch 9
#     loss = 1.708640
#   optimizing batch 10
#     loss = 0.833130
# ===
# Epoch 58 Results:
#   train_loss = 19.964155
#   test_loss = 10.606239
# Beginning Epoch 59
#   optimizing batch 0
#     loss = 1.700341
#   optimizing batch 1
#     loss = 1.485402
#   optimizing batch 2
#     loss = 1.734910
#   optimizing batch 3
#     loss = 1.739012
#   optimizing batch 4
#     loss = 1.665992
#   optimizing batch 5
#     loss = 1.693077
#   optimizing batch 6
#     loss = 1.587132
#   optimizing batch 7
#     loss = 1.554789
#   optimizing batch 8
#     loss = 1.505828
#   optimizing batch 9
#     loss = 1.634056
#   optimizing batch 10
#     loss = 0.762052
# ===
# Epoch 59 Results:
#   train_loss = 17.062590
#   test_loss = 10.416436
# Beginning Epoch 60
#   optimizing batch 0
#     loss = 1.663826
#   optimizing batch 1
#     loss = 1.900515
#   optimizing batch 2
#     loss = 1.435885
#   optimizing batch 3
#     loss = 1.848703
#   optimizing batch 4
#     loss = 1.404390
#   optimizing batch 5
#     loss = 1.858796
#   optimizing batch 6
#     loss = 1.751473
#   optimizing batch 7
#     loss = 1.892492
#   optimizing batch 8
#     loss = 1.410392
#   optimizing batch 9
#     loss = 1.671626
#   optimizing batch 10
#     loss = 0.778870
# ===
# Epoch 60 Results:
#   train_loss = 17.616966
#   test_loss = 10.445108
# Beginning Epoch 61
#   optimizing batch 0
#     loss = 1.578586
#   optimizing batch 1
#     loss = 2.001482
#   optimizing batch 2
#     loss = 1.888534
#   optimizing batch 3
#     loss = 1.438091
#   optimizing batch 4
#     loss = 1.441894
#   optimizing batch 5
#     loss = 1.821496
#   optimizing batch 6
#     loss = 1.940665
#   optimizing batch 7
#     loss = 1.422011
#   optimizing batch 8
#     loss = 1.589659
#   optimizing batch 9
#     loss = 2.458945
#   optimizing batch 10
#     loss = 0.701587
# ===
# Epoch 61 Results:
#   train_loss = 18.282948
#   test_loss = 11.499708
# Beginning Epoch 62
#   optimizing batch 0
#     loss = 2.502416
#   optimizing batch 1
#     loss = 2.192316
#   optimizing batch 2
#     loss = 1.641684
#   optimizing batch 3
#     loss = 3.043885
#   optimizing batch 4
#     loss = 1.508373
#   optimizing batch 5
#     loss = 3.147564
#   optimizing batch 6
#     loss = 1.962611
#   optimizing batch 7
#     loss = 3.720824
#   optimizing batch 8
#     loss = 2.167340
#   optimizing batch 9
#     loss = 4.065785
#   optimizing batch 10
#     loss = 2.068783
# ===
# Epoch 62 Results:
#   train_loss = 28.021583
#   test_loss = 12.246396
# Beginning Epoch 63
#   optimizing batch 0
#     loss = 2.777862
#   optimizing batch 1
#     loss = 4.032534
#   optimizing batch 2
#     loss = 3.339943
#   optimizing batch 3
#     loss = 2.972081
#   optimizing batch 4
#     loss = 3.491899
#   optimizing batch 5
#     loss = 2.032849
#   optimizing batch 6
#     loss = 3.137778
#   optimizing batch 7
#     loss = 2.217105
#   optimizing batch 8
#     loss = 2.744771
#   optimizing batch 9
#     loss = 2.081357
#   optimizing batch 10
#     loss = 1.004397
# ===
# Epoch 63 Results:
#   train_loss = 29.832577
#   test_loss = 10.821070
# Beginning Epoch 64
#   optimizing batch 0
#     loss = 1.874317
#   optimizing batch 1
#     loss = 1.921794
#   optimizing batch 2
#     loss = 2.122921
#   optimizing batch 3
#     loss = 1.710222
#   optimizing batch 4
#     loss = 2.019839
#   optimizing batch 5
#     loss = 1.889321
#   optimizing batch 6
#     loss = 1.719278
#   optimizing batch 7
#     loss = 1.531912
#   optimizing batch 8
#     loss = 1.639779
#   optimizing batch 9
#     loss = 1.623763
#   optimizing batch 10
#     loss = 0.770539
# ===
# Epoch 64 Results:
#   train_loss = 18.823684
#   test_loss = 10.555904
# Beginning Epoch 65
#   optimizing batch 0
#     loss = 1.809688
#   optimizing batch 1
#     loss = 1.801729
#   optimizing batch 2
#     loss = 1.486654
#   optimizing batch 3
#     loss = 1.438566
#   optimizing batch 4
#     loss = 1.596007
#   optimizing batch 5
#     loss = 1.515725
#   optimizing batch 6
#     loss = 1.346774
#   optimizing batch 7
#     loss = 1.370357
#   optimizing batch 8
#     loss = 1.339636
#   optimizing batch 9
#     loss = 1.370880
#   optimizing batch 10
#     loss = 0.739102
# ===
# Epoch 65 Results:
#   train_loss = 15.815116
#   test_loss = 10.218366
# Beginning Epoch 66
#   optimizing batch 0
#     loss = 1.361139
#   optimizing batch 1
#     loss = 2.064610
#   optimizing batch 2
#     loss = 1.777149
#   optimizing batch 3
#     loss = 1.305936
#   optimizing batch 4
#     loss = 1.699628
#   optimizing batch 5
#     loss = 1.880866
#   optimizing batch 6
#     loss = 1.311658
#   optimizing batch 7
#     loss = 1.500479
#   optimizing batch 8
#     loss = 1.752502
#   optimizing batch 9
#     loss = 1.570635
#   optimizing batch 10
#     loss = 0.741346
# ===
# Epoch 66 Results:
#   train_loss = 16.965948
#   test_loss = 10.464287
# Beginning Epoch 67
#   optimizing batch 0
#     loss = 1.491390
#   optimizing batch 1
#     loss = 1.945226
#   optimizing batch 2
#     loss = 1.497530
#   optimizing batch 3
#     loss = 1.899933
#   optimizing batch 4
#     loss = 1.482926
#   optimizing batch 5
#     loss = 1.901812
#   optimizing batch 6
#     loss = 1.255815
#   optimizing batch 7
#     loss = 2.101301
#   optimizing batch 8
#     loss = 1.537733
#   optimizing batch 9
#     loss = 1.665977
#   optimizing batch 10
#     loss = 0.894584
# ===
# Epoch 67 Results:
#   train_loss = 17.674227
#   test_loss = 10.551292
# Beginning Epoch 68
#   optimizing batch 0
#     loss = 1.565848
#   optimizing batch 1
#     loss = 2.429756
#   optimizing batch 2
#     loss = 1.513358
#   optimizing batch 3
#     loss = 2.836986
#   optimizing batch 4
#     loss = 1.407541
#   optimizing batch 5
#     loss = 2.507730
#   optimizing batch 6
#     loss = 1.550445
#   optimizing batch 7
#     loss = 1.720585
#   optimizing batch 8
#     loss = 2.190029
#   optimizing batch 9
#     loss = 1.334277
#   optimizing batch 10
#     loss = 1.159493
# ===
# Epoch 68 Results:
#   train_loss = 20.216049
#   test_loss = 10.843526
# Beginning Epoch 69
#   optimizing batch 0
#     loss = 1.926759
#   optimizing batch 1
#     loss = 3.098786
#   optimizing batch 2
#     loss = 2.096615
#   optimizing batch 3
#     loss = 3.130964
#   optimizing batch 4
#     loss = 2.062176
#   optimizing batch 5
#     loss = 3.390025
#   optimizing batch 6
#     loss = 3.148976
#   optimizing batch 7
#     loss = 2.744085
#   optimizing batch 8
#     loss = 2.086070
#   optimizing batch 9
#     loss = 3.164409
#   optimizing batch 10
#     loss = 1.265852
# ===
# Epoch 69 Results:
#   train_loss = 28.114717
#   test_loss = 11.289553
# Beginning Epoch 70
#   optimizing batch 0
#     loss = 1.981975
#   optimizing batch 1
#     loss = 2.118804
#   optimizing batch 2
#     loss = 2.122385
#   optimizing batch 3
#     loss = 1.752604
#   optimizing batch 4
#     loss = 1.870327
#   optimizing batch 5
#     loss = 1.654539
#   optimizing batch 6
#     loss = 2.025401
#   optimizing batch 7
#     loss = 2.227214
#   optimizing batch 8
#     loss = 1.605219
#   optimizing batch 9
#     loss = 2.021956
#   optimizing batch 10
#     loss = 0.826630
# ===
# Epoch 70 Results:
#   train_loss = 20.207054
#   test_loss = 11.231388
# Beginning Epoch 71
#   optimizing batch 0
#     loss = 2.425705
#   optimizing batch 1
#     loss = 2.125624
#   optimizing batch 2
#     loss = 1.731783
#   optimizing batch 3
#     loss = 2.333943
#   optimizing batch 4
#     loss = 1.698674
#   optimizing batch 5
#     loss = 2.689293
#   optimizing batch 6
#     loss = 1.825659
#   optimizing batch 7
#     loss = 3.070406
#   optimizing batch 8
#     loss = 1.899048
#   optimizing batch 9
#     loss = 2.906224
#   optimizing batch 10
#     loss = 1.197518
# ===
# Epoch 71 Results:
#   train_loss = 23.903878
#   test_loss = 10.898433
# Beginning Epoch 72
#   optimizing batch 0
#     loss = 1.786836
#   optimizing batch 1
#     loss = 2.456443
#   optimizing batch 2
#     loss = 1.997929
#   optimizing batch 3
#     loss = 2.203879
#   optimizing batch 4
#     loss = 2.426757
#   optimizing batch 5
#     loss = 1.651669
#   optimizing batch 6
#     loss = 2.230645
#   optimizing batch 7
#     loss = 1.639661
#   optimizing batch 8
#     loss = 1.739021
#   optimizing batch 9
#     loss = 1.840059
#   optimizing batch 10
#     loss = 0.823230
# ===
# Epoch 72 Results:
#   train_loss = 20.796130
#   test_loss = 10.895903
# Beginning Epoch 73
#   optimizing batch 0
#     loss = 1.945995
#   optimizing batch 1
#     loss = 1.779605
#   optimizing batch 2
#     loss = 1.533474
#   optimizing batch 3
#     loss = 1.776549
#   optimizing batch 4
#     loss = 1.756289
#   optimizing batch 5
#     loss = 1.440698
#   optimizing batch 6
#     loss = 1.678162
#   optimizing batch 7
#     loss = 1.669021
#   optimizing batch 8
#     loss = 1.314619
#   optimizing batch 9
#     loss = 1.664909
#   optimizing batch 10
#     loss = 0.750753
# ===
# Epoch 73 Results:
#   train_loss = 17.310073
#   test_loss = 11.122376
# Beginning Epoch 74
#   optimizing batch 0
#     loss = 1.917325
#   optimizing batch 1
#     loss = 1.828223
#   optimizing batch 2
#     loss = 1.332338
#   optimizing batch 3
#     loss = 2.182577
#   optimizing batch 4
#     loss = 1.310268
#   optimizing batch 5
#     loss = 1.893758
#   optimizing batch 6
#     loss = 1.461239
#   optimizing batch 7
#     loss = 1.437748
#   optimizing batch 8
#     loss = 2.040474
#   optimizing batch 9
#     loss = 1.293571
#   optimizing batch 10
#     loss = 0.899011
# ===
# Epoch 74 Results:
#   train_loss = 17.596532
#   test_loss = 10.381797
# Beginning Epoch 75
#   optimizing batch 0
#     loss = 1.277261
#   optimizing batch 1
#     loss = 1.499203
#   optimizing batch 2
#     loss = 1.496899
#   optimizing batch 3
#     loss = 1.221391
#   optimizing batch 4
#     loss = 1.517680
#   optimizing batch 5
#     loss = 1.648858
#   optimizing batch 6
#     loss = 1.257640
#   optimizing batch 7
#     loss = 1.431538
#   optimizing batch 8
#     loss = 1.510419
#   optimizing batch 9
#     loss = 1.286592
#   optimizing batch 10
#     loss = 0.575253
# ===
# Epoch 75 Results:
#   train_loss = 14.722732
#   test_loss = 10.277378
# Beginning Epoch 76
#   optimizing batch 0
#     loss = 1.272785
#   optimizing batch 1
#     loss = 1.516985
#   optimizing batch 2
#     loss = 1.636950
#   optimizing batch 3
#     loss = 1.220987
#   optimizing batch 4
#     loss = 1.211511
#   optimizing batch 5
#     loss = 1.839360
#   optimizing batch 6
#     loss = 1.363389
#   optimizing batch 7
#     loss = 1.327090
#   optimizing batch 8
#     loss = 2.105465
#   optimizing batch 9
#     loss = 1.257481
#   optimizing batch 10
#     loss = 1.062151
# ===
# Epoch 76 Results:
#   train_loss = 15.814153
#   test_loss = 11.054604
# Beginning Epoch 77
#   optimizing batch 0
#     loss = 1.876497
#   optimizing batch 1
#     loss = 2.007876
#   optimizing batch 2
#     loss = 1.723781
#   optimizing batch 3
#     loss = 2.086903
#   optimizing batch 4
#     loss = 1.964878
#   optimizing batch 5
#     loss = 1.504672
#   optimizing batch 6
#     loss = 2.417846
#   optimizing batch 7
#     loss = 1.543174
#   optimizing batch 8
#     loss = 2.268545
#   optimizing batch 9
#     loss = 1.878605
#   optimizing batch 10
#     loss = 1.234631
# ===
# Epoch 77 Results:
#   train_loss = 20.507410
#   test_loss = 11.677287
# Beginning Epoch 78
#   optimizing batch 0
#     loss = 2.578680
#   optimizing batch 1
#     loss = 2.248875
#   optimizing batch 2
#     loss = 1.953061
#   optimizing batch 3
#     loss = 2.691079
#   optimizing batch 4
#     loss = 1.529285
#   optimizing batch 5
#     loss = 2.529363
#   optimizing batch 6
#     loss = 1.611671
#   optimizing batch 7
#     loss = 1.817623
#   optimizing batch 8
#     loss = 1.832930
#   optimizing batch 9
#     loss = 1.468213
#   optimizing batch 10
#     loss = 0.873978
# ===
# Epoch 78 Results:
#   train_loss = 21.134759
#   test_loss = 10.624605
# Beginning Epoch 79
#   optimizing batch 0
#     loss = 1.689569
#   optimizing batch 1
#     loss = 2.300887
#   optimizing batch 2
#     loss = 1.485460
#   optimizing batch 3
#     loss = 2.306005
#   optimizing batch 4
#     loss = 1.546345
#   optimizing batch 5
#     loss = 1.468902
#   optimizing batch 6
#     loss = 1.922670
#   optimizing batch 7
#     loss = 1.362930
#   optimizing batch 8
#     loss = 1.694625
#   optimizing batch 9
#     loss = 1.827028
#   optimizing batch 10
#     loss = 0.653779
# ===
# Epoch 79 Results:
#   train_loss = 18.258202
#   test_loss = 10.651316
# Beginning Epoch 80
#   optimizing batch 0
#     loss = 1.623288
#   optimizing batch 1
#     loss = 1.434923
#   optimizing batch 2
#     loss = 1.344251
#   optimizing batch 3
#     loss = 1.197004
#   optimizing batch 4
#     loss = 1.399897
#   optimizing batch 5
#     loss = 1.410124
#   optimizing batch 6
#     loss = 1.535993
#   optimizing batch 7
#     loss = 1.325245
#   optimizing batch 8
#     loss = 1.253163
#   optimizing batch 9
#     loss = 1.192912
#   optimizing batch 10
#     loss = 0.700161
# ===
# Epoch 80 Results:
#   train_loss = 14.416961
#   test_loss = 10.511403
# Beginning Epoch 81
#   optimizing batch 0
#     loss = 1.627191
#   optimizing batch 1
#     loss = 2.558715
#   optimizing batch 2
#     loss = 1.312020
#   optimizing batch 3
#     loss = 2.410506
#   optimizing batch 4
#     loss = 1.426097
#   optimizing batch 5
#     loss = 3.188758
#   optimizing batch 6
#     loss = 1.639087
#   optimizing batch 7
#     loss = 3.369841
#   optimizing batch 8
#     loss = 3.414418
#   optimizing batch 9
#     loss = 1.829225
#   optimizing batch 10
#     loss = 1.245356
# ===
# Epoch 81 Results:
#   train_loss = 24.021215
#   test_loss = 11.271534
# Beginning Epoch 82
#   optimizing batch 0
#     loss = 2.193855
#   optimizing batch 1
#     loss = 2.892134
#   optimizing batch 2
#     loss = 2.256750
#   optimizing batch 3
#     loss = 2.640019
#   optimizing batch 4
#     loss = 1.964793
#   optimizing batch 5
#     loss = 3.155102
#   optimizing batch 6
#     loss = 1.851818
#   optimizing batch 7
#     loss = 3.161746
#   optimizing batch 8
#     loss = 1.794438
#   optimizing batch 9
#     loss = 3.201252
#   optimizing batch 10
#     loss = 1.012002
# ===
# Epoch 82 Results:
#   train_loss = 26.123909
#   test_loss = 11.236290
# Beginning Epoch 83
#   optimizing batch 0
#     loss = 2.166588
#   optimizing batch 1
#     loss = 1.874945
#   optimizing batch 2
#     loss = 2.103332
#   optimizing batch 3
#     loss = 1.587422
#   optimizing batch 4
#     loss = 2.015076
#   optimizing batch 5
#     loss = 1.639669
#   optimizing batch 6
#     loss = 1.600352
#   optimizing batch 7
#     loss = 1.654504
#   optimizing batch 8
#     loss = 1.585773
#   optimizing batch 9
#     loss = 1.824939
#   optimizing batch 10
#     loss = 0.774564
# ===
# Epoch 83 Results:
#   train_loss = 18.827163
#   test_loss = 10.729112
# Beginning Epoch 84
#   optimizing batch 0
#     loss = 1.748649
#   optimizing batch 1
#     loss = 1.778955
#   optimizing batch 2
#     loss = 1.483465
#   optimizing batch 3
#     loss = 1.806778
#   optimizing batch 4
#     loss = 1.534545
#   optimizing batch 5
#     loss = 1.467223
#   optimizing batch 6
#     loss = 1.590374
#   optimizing batch 7
#     loss = 1.466085
#   optimizing batch 8
#     loss = 1.258729
#   optimizing batch 9
#     loss = 1.249231
#   optimizing batch 10
#     loss = 0.685634
# ===
# Epoch 84 Results:
#   train_loss = 16.069667
#   test_loss = 10.258547
# Beginning Epoch 85
#   optimizing batch 0
#     loss = 1.291031
#   optimizing batch 1
#     loss = 1.229170
#   optimizing batch 2
#     loss = 1.177395
#   optimizing batch 3
#     loss = 1.489220
#   optimizing batch 4
#     loss = 1.296302
#   optimizing batch 5
#     loss = 1.190655
#   optimizing batch 6
#     loss = 1.949725
#   optimizing batch 7
#     loss = 1.282785
#   optimizing batch 8
#     loss = 1.301890
#   optimizing batch 9
#     loss = 1.875565
#   optimizing batch 10
#     loss = 0.593188
# ===
# Epoch 85 Results:
#   train_loss = 14.676925
#   test_loss = 10.874853
# Beginning Epoch 86
#   optimizing batch 0
#     loss = 1.774727
#   optimizing batch 1
#     loss = 1.533780
#   optimizing batch 2
#     loss = 1.168720
#   optimizing batch 3
#     loss = 1.940745
#   optimizing batch 4
#     loss = 1.243569
#   optimizing batch 5
#     loss = 1.353905
#   optimizing batch 6
#     loss = 1.694964
#   optimizing batch 7
#     loss = 1.229059
#   optimizing batch 8
#     loss = 1.373176
#   optimizing batch 9
#     loss = 1.297006
#   optimizing batch 10
#     loss = 0.663540
# ===
# Epoch 86 Results:
#   train_loss = 15.273193
#   test_loss = 10.327320
# Beginning Epoch 87
#   optimizing batch 0
#     loss = 1.410866
#   optimizing batch 1
#     loss = 2.104515
#   optimizing batch 2
#     loss = 1.180048
#   optimizing batch 3
#     loss = 1.868473
#   optimizing batch 4
#     loss = 1.293327
#   optimizing batch 5
#     loss = 1.723512
#   optimizing batch 6
#     loss = 1.834458
#   optimizing batch 7
#     loss = 1.269632
#   optimizing batch 8
#     loss = 1.272249
#   optimizing batch 9
#     loss = 1.407728
#   optimizing batch 10
#     loss = 0.607094
# ===
# Epoch 87 Results:
# ...
#     loss = 1.412228
#   optimizing batch 10
#     loss = 0.491052
# ===
# Epoch 124 Results:
#   train_loss = 14.384907
#   test_loss = 10.605137
# Beginning Epoch 125
#   optimizing batch 0
#     loss = 1.607182
#   optimizing batch 1
#     loss = 1.310460
#   optimizing batch 2
#     loss = 1.021579
#   optimizing batch 3
#     loss = 1.523717
#   optimizing batch 4
#     loss = 1.124256
#   optimizing batch 5
#     loss = 1.092490
#   optimizing batch 6
#     loss = 1.618955
#   optimizing batch 7
#     loss = 0.990418
#   optimizing batch 8
#     loss = 1.544041
#   optimizing batch 9
#     loss = 1.310940
#   optimizing batch 10
#     loss = 0.473990
# ===
# Epoch 125 Results:
#   train_loss = 13.618029
#   test_loss = 10.224457
# Beginning Epoch 126
#   optimizing batch 0
#     loss = 1.207818
#   optimizing batch 1
#     loss = 1.012322
#   optimizing batch 2
#     loss = 0.990437
#   optimizing batch 3
#     loss = 1.211694
#   optimizing batch 4
#     loss = 1.227417
#   optimizing batch 5
#     loss = 0.917965
#   optimizing batch 6
#     loss = 0.920261
#   optimizing batch 7
#     loss = 0.988428
#   optimizing batch 8
#     loss = 0.957065
#   optimizing batch 9
#     loss = 0.875913
#   optimizing batch 10
#     loss = 0.604355
# ===
# Epoch 126 Results:
#   train_loss = 10.913674
#   test_loss = 10.051269
# Beginning Epoch 127
#   optimizing batch 0
#     loss = 0.994757
#   optimizing batch 1
#     loss = 1.304326
#   optimizing batch 2
#     loss = 1.215293
#   optimizing batch 3
#     loss = 0.970633
#   optimizing batch 4
#     loss = 1.050722
#   optimizing batch 5
#     loss = 1.404867
#   optimizing batch 6
#     loss = 0.996949
#   optimizing batch 7
#     loss = 0.908651
#   optimizing batch 8
#     loss = 1.143786
#   optimizing batch 9
#     loss = 1.016991
#   optimizing batch 10
#     loss = 0.574695
# ===
# Epoch 127 Results:
#   train_loss = 11.581669
#   test_loss = 10.281714
# Beginning Epoch 128
#   optimizing batch 0
#     loss = 1.242142
#   optimizing batch 1
#     loss = 1.618822
#   optimizing batch 2
#     loss = 1.170756
#   optimizing batch 3
#     loss = 1.734259
#   optimizing batch 4
#     loss = 1.221949
#   optimizing batch 5
#     loss = 1.170359
#   optimizing batch 6
#     loss = 1.242076
#   optimizing batch 7
#     loss = 1.363273
#   optimizing batch 8
#     loss = 0.970754
#   optimizing batch 9
#     loss = 1.368166
#   optimizing batch 10
#     loss = 0.529947
# ===
# Epoch 128 Results:
#   train_loss = 13.632502
#   test_loss = 10.438412
# Beginning Epoch 129
#   optimizing batch 0
#     loss = 1.428848
#   optimizing batch 1
#     loss = 1.339715
#   optimizing batch 2
#     loss = 1.066235
#   optimizing batch 3
#     loss = 1.764190
#   optimizing batch 4
#     loss = 1.231023
#   optimizing batch 5
#     loss = 1.045358
#   optimizing batch 6
#     loss = 1.593808
#   optimizing batch 7
#     loss = 1.125284
#   optimizing batch 8
#     loss = 1.146850
#   optimizing batch 9
#     loss = 1.599627
#   optimizing batch 10
#     loss = 0.514851
# ===
# Epoch 129 Results:
#   train_loss = 13.855789
#   test_loss = 10.523772
# Beginning Epoch 130
#   optimizing batch 0
#     loss = 1.565186
#   optimizing batch 1
#     loss = 1.368183
#   optimizing batch 2
#     loss = 0.993882
#   optimizing batch 3
#     loss = 1.017857
#   optimizing batch 4
#     loss = 1.146864
#   optimizing batch 5
#     loss = 1.211088
#   optimizing batch 6
#     loss = 1.059992
#   optimizing batch 7
#     loss = 1.001211
#   optimizing batch 8
#     loss = 1.053294
#   optimizing batch 9
#     loss = 1.114570
#   optimizing batch 10
#     loss = 0.505845
# ===
# Epoch 130 Results:
#   train_loss = 12.037974
#   test_loss = 10.075518
# Beginning Epoch 131
#   optimizing batch 0
#     loss = 1.209566
#   optimizing batch 1
#     loss = 1.664217
#   optimizing batch 2
#     loss = 0.972277
#   optimizing batch 3
#     loss = 1.937760
#   optimizing batch 4
#     loss = 0.942778
#   optimizing batch 5
#     loss = 1.791195
#   optimizing batch 6
#     loss = 1.001521
#   optimizing batch 7
#     loss = 1.346760
#   optimizing batch 8
#     loss = 1.331133
#   optimizing batch 9
#     loss = 0.952085
#   optimizing batch 10
#     loss = 0.731066
# ===
# Epoch 131 Results:
#   train_loss = 13.880358
#   test_loss = 10.147857
# Beginning Epoch 132
#   optimizing batch 0
#     loss = 1.165375
#   optimizing batch 1
#     loss = 1.582105
#   optimizing batch 2
#     loss = 1.128141
#   optimizing batch 3
#     loss = 1.205471
#   optimizing batch 4
#     loss = 1.266672
#   optimizing batch 5
#     loss = 1.094704
#   optimizing batch 6
#     loss = 1.035239
#   optimizing batch 7
#     loss = 1.173645
#   optimizing batch 8
#     loss = 0.919919
#   optimizing batch 9
#     loss = 1.119281
#   optimizing batch 10
#     loss = 0.485802
# ===
# Epoch 132 Results:
#   train_loss = 12.176354
#   test_loss = 10.228707
# Beginning Epoch 133
#   optimizing batch 0
#     loss = 1.263296
#   optimizing batch 1
#     loss = 1.179917
#   optimizing batch 2
#     loss = 1.221650
#   optimizing batch 3
#     loss = 0.953340
#   optimizing batch 4
#     loss = 1.346320
#   optimizing batch 5
#     loss = 1.248528
#   optimizing batch 6
#     loss = 0.851746
#   optimizing batch 7
#     loss = 0.982023
#   optimizing batch 8
#     loss = 1.172704
#   optimizing batch 9
#     loss = 1.074399
#   optimizing batch 10
#     loss = 0.441940
# ===
# Epoch 133 Results:
#   train_loss = 11.735864
#   test_loss = 10.222067
# Beginning Epoch 134
#   optimizing batch 0
#     loss = 1.033576
#   optimizing batch 1
#     loss = 1.306144
#   optimizing batch 2
#     loss = 1.062410
#   optimizing batch 3
#     loss = 0.897040
#   optimizing batch 4
#     loss = 1.139632
#   optimizing batch 5
#     loss = 1.483844
#   optimizing batch 6
#     loss = 0.908423
#   optimizing batch 7
#     loss = 1.478345
#   optimizing batch 8
#     loss = 1.262018
#   optimizing batch 9
#     loss = 1.171597
#   optimizing batch 10
#     loss = 0.778757
# ===
# Epoch 134 Results:
#   train_loss = 12.521787
#   test_loss = 10.700860
# Beginning Epoch 135
#   optimizing batch 0
#     loss = 1.664427
#   optimizing batch 1
#     loss = 1.924173
#   optimizing batch 2
#     loss = 1.435216
#   optimizing batch 3
#     loss = 2.198689
#   optimizing batch 4
#     loss = 1.638955
#   optimizing batch 5
#     loss = 2.848552
#   optimizing batch 6
#     loss = 2.471800
#   optimizing batch 7
#     loss = 1.677092
#   optimizing batch 8
#     loss = 1.643997
#   optimizing batch 9
#     loss = 2.796213
#   optimizing batch 10
#     loss = 0.800338
# ===
# Epoch 135 Results:
#   train_loss = 21.099452
#   test_loss = 11.387335
# Beginning Epoch 136
#   optimizing batch 0
#     loss = 2.393251
#   optimizing batch 1
#     loss = 1.381276
#   optimizing batch 2
#     loss = 2.094701
#   optimizing batch 3
#     loss = 1.437020
#   optimizing batch 4
#     loss = 2.067222
#   optimizing batch 5
#     loss = 1.560911
#   optimizing batch 6
#     loss = 1.522795
#   optimizing batch 7
#     loss = 1.546566
#   optimizing batch 8
#     loss = 1.340951
#   optimizing batch 9
#     loss = 1.342838
#   optimizing batch 10
#     loss = 0.622805
# ===
# Epoch 136 Results:
#   train_loss = 17.310336
#   test_loss = 10.487081
# Beginning Epoch 137
#   optimizing batch 0
#     loss = 1.488020
#   optimizing batch 1
#     loss = 1.347030
#   optimizing batch 2
#     loss = 1.280658
#   optimizing batch 3
#     loss = 1.812776
#   optimizing batch 4
#     loss = 1.350587
#   optimizing batch 5
#     loss = 1.265554
#   optimizing batch 6
#     loss = 1.385517
#   optimizing batch 7
#     loss = 1.112490
#   optimizing batch 8
#     loss = 1.155466
#   optimizing batch 9
#     loss = 1.261964
#   optimizing batch 10
#     loss = 0.581971
# ===
# Epoch 137 Results:
#   train_loss = 14.042032
#   test_loss = 10.440198
# Beginning Epoch 138
#   optimizing batch 0
#     loss = 1.442105
#   optimizing batch 1
#     loss = 1.762052
#   optimizing batch 2
#     loss = 1.075744
#   optimizing batch 3
#     loss = 1.934020
#   optimizing batch 4
#     loss = 1.077273
#   optimizing batch 5
#     loss = 2.150585
#   optimizing batch 6
#     loss = 1.113710
#   optimizing batch 7
#     loss = 1.707616
#   optimizing batch 8
#     loss = 1.175998
#   optimizing batch 9
#     loss = 1.417123
#   optimizing batch 10
#     loss = 0.655838
# ===
# Epoch 138 Results:
#   train_loss = 15.512064
#   test_loss = 10.848131
# Beginning Epoch 139
#   optimizing batch 0
#     loss = 1.799454
#   optimizing batch 1
#     loss = 1.380842
#   optimizing batch 2
#     loss = 1.364841
#   optimizing batch 3
#     loss = 1.784516
#   optimizing batch 4
#     loss = 1.253917
#   optimizing batch 5
#     loss = 1.449336
#   optimizing batch 6
#     loss = 1.248988
#   optimizing batch 7
#     loss = 1.475457
#   optimizing batch 8
#     loss = 1.544979
#   optimizing batch 9
#     loss = 1.082344
#   optimizing batch 10
#     loss = 0.694044
# ===
# Epoch 139 Results:
#   train_loss = 15.078718
#   test_loss = 10.380763
# Beginning Epoch 140
#   optimizing batch 0
#     loss = 1.360445
#   optimizing batch 1
#     loss = 1.623147
#   optimizing batch 2
#     loss = 1.136012
#   optimizing batch 3
#     loss = 1.703243
#   optimizing batch 4
#     loss = 1.101848
#   optimizing batch 5
#     loss = 1.767424
#   optimizing batch 6
#     loss = 1.152517
#   optimizing batch 7
#     loss = 1.407587
#   optimizing batch 8
#     loss = 1.229482
#   optimizing batch 9
#     loss = 1.145792
#   optimizing batch 10
#     loss = 0.682233
# ===
# Epoch 140 Results:
#   train_loss = 14.309731
#   test_loss = 10.475248
# Beginning Epoch 141
#   optimizing batch 0
#     loss = 1.477314
#   optimizing batch 1
#     loss = 1.604409
#   optimizing batch 2
#     loss = 1.189017
#   optimizing batch 3
#     loss = 1.660259
#   optimizing batch 4
#     loss = 1.087842
#   optimizing batch 5
#     loss = 1.274852
#   optimizing batch 6
#     loss = 1.161583
#   optimizing batch 7
#     loss = 1.133897
#   optimizing batch 8
#     loss = 1.116462
#   optimizing batch 9
#     loss = 1.193017
#   optimizing batch 10
#     loss = 0.552378
# ===
# Epoch 141 Results:
#   train_loss = 13.451031
#   test_loss = 10.019441
# Beginning Epoch 142
#   optimizing batch 0
#     loss = 1.086618
#   optimizing batch 1
#     loss = 0.953848
#   optimizing batch 2
#     loss = 1.055696
#   optimizing batch 3
#     loss = 0.970783
#   optimizing batch 4
#     loss = 0.956840
#   optimizing batch 5
#     loss = 0.934238
#   optimizing batch 6
#     loss = 0.883787
#   optimizing batch 7
#     loss = 0.985549
#   optimizing batch 8
#     loss = 1.031157
#   optimizing batch 9
#     loss = 1.325128
#   optimizing batch 10
#     loss = 0.465645
# ===
# Epoch 142 Results:
#   train_loss = 10.649289
#   test_loss = 10.277776
# Beginning Epoch 143
#   optimizing batch 0
#     loss = 1.415302
#   optimizing batch 1
#     loss = 1.503966
#   optimizing batch 2
#     loss = 0.952698
#   optimizing batch 3
#     loss = 1.725662
#   optimizing batch 4
#     loss = 1.158212
#   optimizing batch 5
#     loss = 1.115857
#   optimizing batch 6
#     loss = 1.554801
#   optimizing batch 7
#     loss = 1.028150
#   optimizing batch 8
#     loss = 1.014849
#   optimizing batch 9
#     loss = 1.438192
#   optimizing batch 10
#     loss = 0.488470
# ===
# Epoch 143 Results:
#   train_loss = 13.396158
#   test_loss = 10.409603
# Beginning Epoch 144
#   optimizing batch 0
#     loss = 1.342578
#   optimizing batch 1
#     loss = 1.431629
#   optimizing batch 2
#     loss = 0.915563
#   optimizing batch 3
#     loss = 1.482853
#   optimizing batch 4
#     loss = 1.039571
#   optimizing batch 5
#     loss = 1.026091
#   optimizing batch 6
#     loss = 0.910208
#   optimizing batch 7
#     loss = 1.027092
#   optimizing batch 8
#     loss = 0.845933
#   optimizing batch 9
#     loss = 0.963363
#   optimizing batch 10
#     loss = 0.599062
# ===
# Epoch 144 Results:
#   train_loss = 11.583943
#   test_loss = 10.022308
# Beginning Epoch 145
#   optimizing batch 0
#     loss = 1.097862
#   optimizing batch 1
#     loss = 1.939947
#   optimizing batch 2
#     loss = 1.172850
#   optimizing batch 3
#     loss = 2.523983
#   optimizing batch 4
#     loss = 1.452353
#   optimizing batch 5
#     loss = 2.442884
#   optimizing batch 6
#     loss = 2.294389
#   optimizing batch 7
#     loss = 1.554895
#   optimizing batch 8
#     loss = 1.607415
#   optimizing batch 9
#     loss = 2.800722
#   optimizing batch 10
#     loss = 0.671929
# ===
# Epoch 145 Results:
#   train_loss = 19.559229
#   test_loss = 11.149752
# Beginning Epoch 146
#   optimizing batch 0
#     loss = 2.235192
#   optimizing batch 1
#     loss = 1.264812
#   optimizing batch 2
#     loss = 2.570545
#   optimizing batch 3
#     loss = 1.713719
#   optimizing batch 4
#     loss = 2.683593
#   optimizing batch 5
#     loss = 1.622023
#   optimizing batch 6
#     loss = 3.393147
#   optimizing batch 7
#     loss = 2.185524
#   optimizing batch 8
#     loss = 2.987999
#   optimizing batch 9
#     loss = 1.754706
#   optimizing batch 10
#     loss = 2.045967
# ===
# Epoch 146 Results:
#   train_loss = 24.457226
#   test_loss = 15.484944
# Beginning Epoch 147
#   optimizing batch 0
#     loss = 4.339126
#   optimizing batch 1
#     loss = 2.296765
#   optimizing batch 2
#     loss = 2.325925
#   optimizing batch 3
#     loss = 3.377747
#   optimizing batch 4
#     loss = 2.266649
#   optimizing batch 5
#     loss = 3.308292
#   optimizing batch 6
#     loss = 2.334488
#   optimizing batch 7
#     loss = 4.250699
#   optimizing batch 8
#     loss = 3.076083
#   optimizing batch 9
#     loss = 3.614262
#   optimizing batch 10
#     loss = 1.034173
# ===
# Epoch 147 Results:
#   train_loss = 32.224209
#   test_loss = 13.113112
# Beginning Epoch 148
#   optimizing batch 0
#     loss = 3.162502
#   optimizing batch 1
#     loss = 1.993948
#   optimizing batch 2
#     loss = 1.818565
#   optimizing batch 3
#     loss = 2.905820
#   optimizing batch 4
#     loss = 2.510138
#   optimizing batch 5
#     loss = 2.053661
#   optimizing batch 6
#     loss = 2.302525
#   optimizing batch 7
#     loss = 2.251831
#   optimizing batch 8
#     loss = 1.597338
#   optimizing batch 9
#     loss = 2.364394
#   optimizing batch 10
#     loss = 0.825389
# ===
# Epoch 148 Results:
#   train_loss = 23.786110
#   test_loss = 10.963238
# Beginning Epoch 149
#   optimizing batch 0
#     loss = 2.068066
#   optimizing batch 1
#     loss = 1.709443
#   optimizing batch 2
#     loss = 1.575313
#   optimizing batch 3
#     loss = 1.718547
#   optimizing batch 4
#     loss = 1.471823
#   optimizing batch 5
#     loss = 1.631142
#   optimizing batch 6
#     loss = 1.460747
#   optimizing batch 7
#     loss = 1.515211
#   optimizing batch 8
#     loss = 1.557780
#   optimizing batch 9
#     loss = 1.330756
#   optimizing batch 10
#     loss = 0.754628
# ===
# Epoch 149 Results:
#   train_loss = 16.793456
#   test_loss = 10.447866
# Beginning Epoch 150
#   optimizing batch 0
#     loss = 1.483529
#   optimizing batch 1
#     loss = 1.524594
#   optimizing batch 2
#     loss = 1.351477
#   optimizing batch 3
#     loss = 1.466231
#   optimizing batch 4
#     loss = 1.420242
#   optimizing batch 5
#     loss = 1.467214
#   optimizing batch 6
#     loss = 1.211225
#   optimizing batch 7
#     loss = 1.355655
#   optimizing batch 8
#     loss = 1.456629
#   optimizing batch 9
#     loss = 1.343052
#   optimizing batch 10
#     loss = 0.589073
# ===
# Epoch 150 Results:
#   train_loss = 14.668922
#   test_loss = 10.155298
# Beginning Epoch 151
#   optimizing batch 0
#     loss = 1.349834
#   optimizing batch 1
#     loss = 1.299214
#   optimizing batch 2
#     loss = 1.137666
#   optimizing batch 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 23
#      20 output = model(x)
#      21 loss = loss_func(output.view(bsz, -1),
#      22                   label.view(bsz, -1))
# ---> 23 loss.backward()
#      24 optimizer.step()
#      26 print("    loss = %f" % loss.item())
#
# File ~/miniconda3/envs/cem38/lib/python3.8/site-packages/torch/_tensor.py:488, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     478 if has_torch_function_unary(self):
#     479     return handle_torch_function(
#     480         Tensor.backward,
#     481         (self,),
#    (...)
#     486         inputs=inputs,
#     487     )
# --> 488 torch.autograd.backward(
#     489     self, gradient, retain_graph, create_graph, inputs=inputs
#     490 )
#
# File ~/miniconda3/envs/cem38/lib/python3.8/site-packages/torch/autograd/__init__.py:197, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     192     retain_graph = create_graph
#     194 # The reason we repeat same the comment below is that
#     195 # some Python versions print out the first line of a multi-line function
#     196 # calls in the traceback and some print out the last line
# --> 197 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     198     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     199     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
# torch.save(model.state_dict(), "checkpoints/fno2d-jic.pt")

def gaussian_normalize(x): 
    mean = torch.mean(x)
    std = torch.std(x)
    eps = 0.00001
    return (x - mean) / (std + eps)

with torch.no_grad(): 
    demo_x, demo_label = test_datasets[22]
    demo_y = model(demo_x[None, ...]).squeeze(0)
    demo_label = gaussian_normalize(demo_label)
    demo_y = gaussian_normalize(demo_y)
    fig, axes = plt.subplots(1, 3)
    axes[0].imshow(demo_x.permute(1, 2, 0))
    axes[1].imshow(demo_y.permute(1, 2, 0))
    axes[2].imshow(demo_label.permute(1, 2, 0))
    axes[0].set_title("Input")
    axes[1].set_title("Predicted")
    axes[2].set_title("Actual")

# %%
with torch.no_grad(): 
    x = np.zeros((1, 140, 140, 1))
    x[:, 65, 65, :] = 1
    x[:, 75, 75, :] = 1
    x[:, 65, 75, :] = 1
    x[:, 75, 65, :] = 1
    x = torch.Tensor(x)
    y = model(x.permute(0, 3, 1, 2))
    fig, axes = plt.subplots(1, 2)
    axes[0].imshow(x.squeeze(0))
    axes[1].imshow(y.squeeze(0).permute(1, 2, 0))

# %%
# !ls -alh checkpoints
# Out:
# total 524832
# drwxr-xr-x  3 winnaries  staff    96B Jan 10 23:03 .
# drwxr-xr-x  8 winnaries  staff   256B Jan 10 23:02 ..
# -rw-r--r--  1 winnaries  staff   256M Jan 10 23:02 fno2d.pt

# %%
# !ls checkpoints/
# Out:
# fno2d.pt models

# %%
plt.plot(train_plot, label="Train")
plt.plot(test_plot, label="Test")
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')

# %% [markdown]
# ### FNOv2

# %%
class AntennaImageDatasetV3(Dataset): 
    def __init__(self, folder_path): 
        self.label_path = os.path.join(folder_path, 'labels')
        self.input_path = os.path.join(folder_path, 'x')
        self.len = None
        
    def __len__(self): 
        if self.len == None: 
            self.len = 0
            for name in os.listdir(self.label_path):
                if ".npy" in name: 
                    self.len += 1
        return self.len
        
    def __getitem__(self, idx): 
        input_path = os.path.join(self.input_path, 'train_%04d.npy' % idx)
        label_path = os.path.join(self.label_path, 'train_%04d_label.npy' % idx)
        
        sources_img = torch.Tensor(np.load(input_path)).squeeze().permute(1, 2, 0)
        label_img = torch.Tensor(np.load(label_path))
        
        return sources_img[...], label_img[..., None]

# %%
datasets = AntennaImageDatasetV3('/media/winnaries/Susano/kth/hpc/amphases_patterns/')
demo_sources, demo_label = datasets[192]

fig, axes = plt.subplots(1, 3, dpi=120, figsize=(8, 8))
axes[0].imshow(demo_sources[:, :, 0])
axes[1].imshow(demo_sources[:, :, 1], cmap="twilight")
axes[2].imshow(demo_label)

demo_sources.shape, demo_label.shape, len(datasets)
# Out:
# (torch.Size([140, 140, 2]), torch.Size([140, 140, 1]), 2000)

# %%
torch.manual_seed(123)
train_datasets, test_datasets = random_split(datasets, [1760, 240])
train_dataloader = DataLoader(train_datasets, batch_size=32, shuffle=True)
test_dataloader = DataLoader(test_datasets, batch_size=32, shuffle=True)

# %%
class FNO2dV2(nn.Module): 
    def __init__(self, modes1, modes2, width): 
        super().__init__()
        self.modes1 = modes1
        self.modes2 = modes2
        self.width = width
        self.padding = 9
        
        self.p = nn.Linear(5, self.width)
        self.conv0 = SpectralConv2d(self.width, self.width, self.modes1, self.modes2)
        self.conv1 = SpectralConv2d(self.width, self.width, self.modes1, self.modes2)
        self.conv2 = SpectralConv2d(self.width, self.width, self.modes1, self.modes2)
        self.conv3 = SpectralConv2d(self.width, self.width, self.modes1, self.modes2)
        self.mlp0 = MLP(self.width, self.width, self.width)
        self.mlp1 = MLP(self.width, self.width, self.width)
        self.mlp2 = MLP(self.width, self.width, self.width)
        self.mlp3 = MLP(self.width, self.width, self.width)
        self.w0 = nn.Conv2d(self.width, self.width, 1)
        self.w1 = nn.Conv2d(self.width, self.width, 1)
        self.w2 = nn.Conv2d(self.width, self.width, 1)
        self.w3 = nn.Conv2d(self.width, self.width, 1)
        self.q = MLP(self.width, 1, self.width * 4)
        
    def forward(self, sources):
        amplitudes = sources[..., 0:1]
        phases = sources[..., 1:2]
        phasesX = torch.cos(phases)
        phasesY = torch.sin(phases)
        
        grid = self.get_grid(sources.shape, sources.device)
        x = torch.cat((amplitudes, phasesX, phasesY, grid), dim=-1)
        
        x = self.p(x).permute(0, 3, 1, 2)
        x = F.pad(x, [0,self.padding, 0,self.padding])

        x1 = self.conv0(x)
        x1 = self.mlp0(x1)
        x2 = self.w0(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.conv1(x)
        x1 = self.mlp1(x1)
        x2 = self.w1(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.conv2(x)
        x1 = self.mlp2(x1)
        x2 = self.w2(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.conv3(x)
        x1 = self.mlp3(x1)
        x2 = self.w3(x)
        x = x1 + x2

        x = x[..., :-self.padding, :-self.padding]
        x = self.q(x)
        return x

    def get_grid(self, shape, device):
        batchsize, size_x, size_y = shape[0], shape[1], shape[2]
        gridx = torch.tensor(np.linspace(0, 1, size_x), dtype=torch.float)
        gridx = gridx.reshape(1, size_x, 1, 1).repeat([batchsize, 1, size_y, 1])
        gridy = torch.tensor(np.linspace(0, 1, size_y), dtype=torch.float)
        gridy = gridy.reshape(1, 1, size_y, 1).repeat([batchsize, size_x, 1, 1])
        return torch.cat((gridx, gridy), dim=-1).to(device)
    
    def get_phase_encoding(self, phases): 
        return F.one_hot((phases.squeeze(-1) / 90).to(dtype=torch.long), num_classes=4)

# %%
model = FNO2dV2(16, 16, 32).cuda()
loss_func = LpLoss()

# %%
train_plot = []
test_plot = []
best = 10000
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

pbar = range(1000)
for epoch in range(1000): 
    model.train()
    train_loss = 0
    test_loss = 0
    
    pbar = tqdm(enumerate(iter(train_dataloader)), total=len(train_dataloader),
                desc="Train Epoch %d" % epoch, ncols=100)
    for i, (sources, label) in pbar:
        sources = sources.cuda()
        label = label.cuda()
        bsz = sources.shape[0]
        optimizer.zero_grad()
        output = model(sources)
        loss = loss_func(output.view(bsz, -1),
                          label.view(bsz, -1))
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        pbar.set_postfix({'train_loss': train_loss / (i + 1)})
    
    model.eval()
    with torch.no_grad(): 
        pbar = tqdm(iter(test_dataloader), desc="Test Epoch %d" % epoch, ncols=100)
        for (sources, label) in pbar: 
            bsz = sources.shape[0]
            sources = sources.cuda()
            label = label.cuda()
            output = model(sources)
            loss = loss_func(output.view(bsz, -1),
                              label.view(bsz, -1))
            test_loss += loss.item()
            pbar.set_postfix({'test_loss': test_loss})

    train_plot.append(train_loss)
    test_plot.append(test_loss)
    
    if test_loss < best: 
        best = test_loss
        torch.save(model.state_dict(), "checkpoints/dephased-fno-best.pt")
# Out:
# Train Epoch 0: 100%|██████████████████████████████| 55/55 [00:14<00:00,  3.67it/s, train_loss=0.699]
# Test Epoch 0: 100%|████████████████████████████████████| 8/8 [00:00<00:00,  9.87it/s, test_loss=4.6]
# Train Epoch 1: 100%|██████████████████████████████| 55/55 [00:15<00:00,  3.62it/s, train_loss=0.567]
# Test Epoch 1: 100%|███████████████████████████████████| 8/8 [00:00<00:00,  9.74it/s, test_loss=4.43]
# Train Epoch 2: 100%|██████████████████████████████| 55/55 [00:15<00:00,  3.60it/s, train_loss=0.564]
# Test Epoch 2: 100%|███████████████████████████████████| 8/8 [00:00<00:00,  9.62it/s, test_loss=4.45]
# Train Epoch 3: 100%|██████████████████████████████| 55/55 [00:15<00:00,  3.58it/s, train_loss=0.564]
# Test Epoch 3: 100%|███████████████████████████████████| 8/8 [00:00<00:00,  9.67it/s, test_loss=4.41]
# Train Epoch 4: 100%|██████████████████████████████| 55/55 [00:15<00:00,  3.52it/s, train_loss=0.563]
# Test Epoch 4: 100%|███████████████████████████████████| 8/8 [00:00<00:00,  9.49it/s, test_loss=4.46]
# Train Epoch 5: 100%|██████████████████████████████| 55/55 [00:15<00:00,  3.48it/s, train_loss=0.565]
# Test Epoch 5: 100%|███████████████████████████████████| 8/8 [00:00<00:00,  9.42it/s, test_loss=4.39]
# Train Epoch 6: 100%|██████████████████████████████| 55/55 [00:15<00:00,  3.51it/s, train_loss=0.561]
# Test Epoch 6: 100%|███████████████████████████████████| 8/8 [00:00<00:00,  9.33it/s, test_loss=4.52]
# Train Epoch 7: 100%|██████████████████████████████| 55/55 [00:15<00:00,  3.49it/s, train_loss=0.563]
# Test Epoch 7: 100%|███████████████████████████████████| 8/8 [00:00<00:00,  9.37it/s, test_loss=4.46]
# Train Epoch 8: 100%|███████████████████████████████| 55/55 [00:15<00:00,  3.49it/s, train_loss=0.56]
# Test Epoch 8: 100%|███████████████████████████████████| 8/8 [00:00<00:00,  9.37it/s, test_loss=4.36]
# Train Epoch 9: 100%|██████████████████████████████| 55/55 [00:15<00:00,  3.49it/s, train_loss=0.543]
# Test Epoch 9: 100%|███████████████████████████████████| 8/8 [00:00<00:00,  9.33it/s, test_loss=4.02]
# Train Epoch 10: 100%|█████████████████████████████| 55/55 [00:15<00:00,  3.49it/s, train_loss=0.485]
# Test Epoch 10: 100%|██████████████████████████████████| 8/8 [00:00<00:00,  9.32it/s, test_loss=3.58]
# Train Epoch 11: 100%|█████████████████████████████| 55/55 [00:15<00:00,  3.48it/s, train_loss=0.436]
# Test Epoch 11: 100%|██████████████████████████████████| 8/8 [00:00<00:00,  9.48it/s, test_loss=3.24]
# Train Epoch 12: 100%|█████████████████████████████| 55/55 [00:15<00:00,  3.49it/s, train_loss=0.407]
# Test Epoch 12: 100%|███████████████████████████████████| 8/8 [00:00<00:00,  9.39it/s, test_loss=3.2]
# Train Epoch 13: 100%|█████████████████████████████| 55/55 [00:15<00:00,  3.48it/s, train_loss=0.401]
# Test Epoch 13: 100%|███████████████████████████████████| 8/8 [00:00<00:00,  9.37it/s, test_loss=3.2]
# Train Epoch 14: 100%|█████████████████████████████| 55/55 [00:15<00:00,  3.48it/s, train_loss=0.399]
# Test Epoch 14: 100%|██████████████████████████████████| 8/8 [00:00<00:00,  9.29it/s, test_loss=3.16]
# Train Epoch 15: 100%|█████████████████████████████| 55/55 [00:15<00:00,  3.48it/s, train_loss=0.398]
# Test Epoch 15: 100%|██████████████████████████████████| 8/8 [00:00<00:00,  9.32it/s, test_loss=3.18]
# Train Epoch 16: 100%|█████████████████████████████| 55/55 [00:15<00:00,  3.48it/s, train_loss=0.395]
# Test Epoch 16: 100%|██████████████████████████████████| 8/8 [00:00<00:00,  9.25it/s, test_loss=3.18]
# Train Epoch 17: 100%|█████████████████████████████| 55/55 [00:15<00:00,  3.48it/s, train_loss=0.395]
# Test Epoch 17: 100%|██████████████████████████████████| 8/8 [00:00<00:00,  9.37it/s, test_loss=3.14]
# Train Epoch 18: 100%|█████████████████████████████| 55/55 [00:15<00:00,  3.48it/s, train_loss=0.393]
# Test Epoch 18: 100%|██████████████████████████████████| 8/8 [00:00<00:00,  9.48it/s, test_loss=3.14]
# Train Epoch 19: 100%|█████████████████████████████| 55/55 [00:15<00:00,  3.48it/s, train_loss=0.394]
# Test Epoch 19: 100%|██████████████████████████████████| 8/8 [00:00<00:00,  9.33it/s, test_loss=3.15]
# Train Epoch 20: 100%|█████████████████████████████| 55/55 [00:15<00:00,  3.47it/s, train_loss=0.393]
# Test Epoch 20: 100%|██████████████████████████████████| 8/8 [00:00<00:00,  9.37it/s, test_loss=3.13]
# Train Epoch 21: 100%|█████████████████████████████| 55/55 [00:15<00:00,  3.49it/s, train_loss=0.392]
# Test Epoch 21: 100%|██████████████████████████████████| 8/8 [00:00<00:00,  9.44it/s, test_loss=3.14]
# Train Epoch 22: 100%|█████████████████████████████| 55/55 [00:15<00:00,  3.48it/s, train_loss=0.392]
# Test Epoch 22: 100%|██████████████████████████████████| 8/8 [00:00<00:00,  9.45it/s, test_loss=3.16]
# Train Epoch 23: 100%|██████████████████████████████| 55/55 [00:15<00:00,  3.45it/s, train_loss=0.39]
# Test Epoch 23: 100%|██████████████████████████████████| 8/8 [00:00<00:00,  8.96it/s, test_loss=3.15]
# Train Epoch 24: 100%|█████████████████████████████| 55/55 [00:15<00:00,  3.51it/s, train_loss=0.392]
# Test Epoch 24: 100%|██████████████████████████████████| 8/8 [00:00<00:00,  9.40it/s, test_loss=3.14]
# Train Epoch 25: 100%|█████████████████████████████| 55/55 [00:16<00:00,  3.26it/s, train_loss=0.391]
# Test Epoch 25: 100%|██████████████████████████████████| 8/8 [00:00<00:00,  8.71it/s, test_loss=3.15]
# Train Epoch 26: 100%|█████████████████████████████| 55/55 [00:17<00:00,  3.16it/s, train_loss=0.389]
# Test Epoch 26: 100%|██████████████████████████████████| 8/8 [00:00<00:00,  8.76it/s, test_loss=3.14]
# Train Epoch 27: 100%|█████████████████████████████| 55/55 [00:16<00:00,  3.38it/s, train_loss=0.388]
# Test Epoch 27: 100%|██████████████████████████████████| 8/8 [00:00<00:00,  9.18it/s, test_loss=3.13]
# Train Epoch 28: 100%|█████████████████████████████| 55/55 [00:15<00:00,  3.49it/s, train_loss=0.388]
# Test Epoch 28: 100%|██████████████████████████████████| 8/8 [00:00<00:00,  9.62it/s, test_loss=3.13]
# Train Epoch 29: 100%|█████████████████████████████| 55/55 [00:16<00:00,  3.40it/s, train_loss=0.389]
# Test Epoch 29: 100%|██████████████████████████████████| 8/8 [00:00<00:00,  9.37it/s, test_loss=3
 100%|███████████████████████████| 55/55 [00:15<00:00,  3.62it/s, train_loss=0.0727]
# Test Epoch 978: 100%|█████████████████████████████████| 8/8 [00:00<00:00,  9.88it/s, test_loss=4.67]
# Train Epoch 979: 100%|███████████████████████████| 55/55 [00:15<00:00,  3.61it/s, train_loss=0.0726]
# Test Epoch 979: 100%|█████████████████████████████████| 8/8 [00:00<00:00,  9.95it/s, test_loss=4.69]
# Train Epoch 980: 100%|███████████████████████████| 55/55 [00:15<00:00,  3.61it/s, train_loss=0.0725]
# Test Epoch 980: 100%|██████████████████████████████████| 8/8 [00:00<00:00,  9.94it/s, test_loss=4.7]
# Train Epoch 981: 100%|███████████████████████████| 55/55 [00:15<00:00,  3.61it/s, train_loss=0.0722]
# Test Epoch 981: 100%|█████████████████████████████████| 8/8 [00:00<00:00,  9.85it/s, test_loss=4.65]
# Train Epoch 982: 100%|███████████████████████████| 55/55 [00:15<00:00,  3.61it/s, train_loss=0.0731]
# Test Epoch 982: 100%|█████████████████████████████████| 8/8 [00:00<00:00,  9.94it/s, test_loss=4.69]
# Train Epoch 983: 100%|███████████████████████████| 55/55 [00:15<00:00,  3.61it/s, train_loss=0.0732]
# Test Epoch 983: 100%|█████████████████████████████████| 8/8 [00:00<00:00, 10.05it/s, test_loss=4.64]
# Train Epoch 984: 100%|███████████████████████████| 55/55 [00:15<00:00,  3.62it/s, train_loss=0.0748]
# Test Epoch 984: 100%|█████████████████████████████████| 8/8 [00:00<00:00,  9.92it/s, test_loss=4.65]
# Train Epoch 985: 100%|███████████████████████████| 55/55 [00:15<00:00,  3.62it/s, train_loss=0.0734]
# Test Epoch 985: 100%|██████████████████████████████████| 8/8 [00:00<00:00,  9.93it/s, test_loss=4.7]
# Train Epoch 986: 100%|███████████████████████████| 55/55 [00:15<00:00,  3.62it/s, train_loss=0.0737]
# Test Epoch 986: 100%|█████████████████████████████████| 8/8 [00:00<00:00,  9.84it/s, test_loss=4.69]
# Train Epoch 987: 100%|███████████████████████████| 55/55 [00:15<00:00,  3.61it/s, train_loss=0.0736]
# Test Epoch 987: 100%|█████████████████████████████████| 8/8 [00:00<00:00,  9.97it/s, test_loss=4.69]
# Train Epoch 988: 100%|████████████████████████████| 55/55 [00:15<00:00,  3.61it/s, train_loss=0.074]
# Test Epoch 988: 100%|█████████████████████████████████| 8/8 [00:00<00:00,  9.85it/s, test_loss=4.75]
# Train Epoch 989: 100%|███████████████████████████| 55/55 [00:15<00:00,  3.62it/s, train_loss=0.0781]
# Test Epoch 989: 100%|█████████████████████████████████| 8/8 [00:00<00:00,  9.98it/s, test_loss=4.65]
# Train Epoch 990: 100%|███████████████████████████| 55/55 [00:15<00:00,  3.62it/s, train_loss=0.0753]
# Test Epoch 990: 100%|█████████████████████████████████| 8/8 [00:00<00:00,  9.88it/s, test_loss=4.66]
# Train Epoch 991: 100%|███████████████████████████| 55/55 [00:15<00:00,  3.62it/s, train_loss=0.0733]
# Test Epoch 991: 100%|█████████████████████████████████| 8/8 [00:00<00:00,  9.89it/s, test_loss=4.69]
# Train Epoch 992: 100%|███████████████████████████| 55/55 [00:15<00:00,  3.62it/s, train_loss=0.0727]
# Test Epoch 992: 100%|█████████████████████████████████| 8/8 [00:00<00:00, 10.00it/s, test_loss=4.67]
# Train Epoch 993: 100%|███████████████████████████| 55/55 [00:15<00:00,  3.61it/s, train_loss=0.0726]
# Test Epoch 993: 100%|█████████████████████████████████| 8/8 [00:00<00:00,  9.91it/s, test_loss=4.66]
# Train Epoch 994: 100%|███████████████████████████| 55/55 [00:15<00:00,  3.61it/s, train_loss=0.0723]
# Test Epoch 994: 100%|█████████████████████████████████| 8/8 [00:00<00:00,  9.94it/s, test_loss=4.65]
# Train Epoch 995: 100%|███████████████████████████| 55/55 [00:15<00:00,  3.61it/s, train_loss=0.0725]
# Test Epoch 995: 100%|█████████████████████████████████| 8/8 [00:00<00:00, 10.03it/s, test_loss=4.66]
# Train Epoch 996: 100%|███████████████████████████| 55/55 [00:15<00:00,  3.61it/s, train_loss=0.0727]
# Test Epoch 996: 100%|█████████████████████████████████| 8/8 [00:00<00:00,  9.87it/s, test_loss=4.68]
# Train Epoch 997: 100%|███████████████████████████| 55/55 [00:15<00:00,  3.62it/s, train_loss=0.0747]
# Test Epoch 997: 100%|██████████████████████████████████| 8/8 [00:00<00:00,  9.82it/s, test_loss=4.7]
# Train Epoch 998: 100%|███████████████████████████| 55/55 [00:15<00:00,  3.62it/s, train_loss=0.0766]
# Test Epoch 998: 100%|█████████████████████████████████| 8/8 [00:00<00:00,  9.95it/s, test_loss=4.64]
# Train Epoch 999: 100%|███████████████████████████| 55/55 [00:15<00:00,  3.62it/s, train_loss=0.0753]
# Test Epoch 999: 100%|█████████████████████████████████| 8/8 [00:00<00:00,  9.86it/s, test_loss=4.66]

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(train_plot, label="Train")
ax.plot(test_plot, label="Test")
ax.legend()
ax.set_xlabel("Epoch")
ax.set_ylabel("Loss")
None

# %%
model.load_state_dict(torch.load('checkpoints/dephased-fno-best.pt'))
fig, axes = plt.subplots(10, 4, figsize=(12, 50))
begin = 10

with torch.no_grad(): 
    for i in range(10): 
        demo_sources, demo_label = test_datasets[begin + i]
        demo_y = model(demo_sources.cuda()[None, ...])
        demo_y = demo_y[0]
        
        demo_y = demo_y / demo_y.max()
        demo_label = demo_label / demo_label.max()
        error = demo_y.permute(1, 2, 0).cpu() - demo_label
        
        axes[i, 0].imshow(demo_sources.cpu()[:, :, 0])
        axes[i, 1].imshow(demo_y.cpu().permute(1, 2, 0))
        axes[i, 2].imshow(demo_label)
        axes[i, 3].imshow(np.abs(error))
        axes[i, 0].set_title("Input")
        axes[i, 1].set_title("Predicted")
        axes[i, 2].set_title("Actual")
    
fig.savefig("fno_demo.png", facecolor="white")

# %%
with torch.no_grad(): 
    x = np.zeros((1, 140, 140, 1))
    
    for i in range(10): 
        idx = 25 + i * 10
        x[:, idx, idx] = 0.2 + abs(i - 5) * 0.2
        
    x = torch.Tensor(x).cuda()
    y = model(x)
    fig, axes = plt.subplots(1, 2, dpi=120)
    axes[0].imshow(x.cpu().squeeze(0))
    axes[1].imshow(y.cpu().squeeze(0).permute(1, 2, 0))

# %%
import time

elapsed = np.zeros(50)
cpu_model = model.cpu()
    
for i in range(50): 
    demo_sources, demo_label = test_datasets[i]
    st = time.time()
    demo_y = cpu_model(demo_sources[None, ...])
    ed = time.time()
    elapsed[i] = ed - st

# %%
np.mean(elapsed), np.std(elapsed)
# Out:
# (0.030596680641174316, 0.004744327961712363)

# %%
from matplotlib import colors

resolution = 10  # pixels/um

sxy = 10
dpml = 2
cell = mp.Vector3(sxy+2*dpml,sxy+2*dpml,0)
pml_layers = [mp.PML(dpml)]

freq = 0.66713 # 200 GHz
geometry = [mp.Block(mp.Vector3(x=mp.inf, y=mp.inf, z=mp.inf),
                     center=mp.Vector3(0, 0, 0),
                     material=mp.Medium(epsilon=1))]
src_cmpt = mp.Ez


def uniform_random_sources(n=None):
    if n is None: n = np.random.randint(2, 4)
    
    points = (sxy * np.random.random(size=(n, 2)) - (sxy/2.0)) * 0.95
    amplitudes = 0.1 + np.random.normal(size=(n), loc=0.9, scale=0.5)
    cent_vec = [mp.Vector3(x=s[0], y=s[1], z=0) for s in points]
    
    sources = [mp.Source(src=mp.ContinuousSource(freq),
                         center=c, component=src_cmpt,
                         amplitude=amp) 
               for amp, c in zip(amplitudes, cent_vec)]
    
    return sources, points, amplitudes

def get_x_img(phasor_arr, points, amps):
    x = np.zeros_like(phasor_arr, dtype=float)
    
    xs = []
    ys = []
    for p in points:
        _fullwidth = 2 * dpml + sxy
        xs.append((x.shape[1]-1)*((p[1]+_fullwidth/2.0)/_fullwidth))
        ys.append((x.shape[0]-1)*((p[0]+_fullwidth/2.0)/_fullwidth))
    xs = np.round(xs).astype(int)
    ys = np.round(ys).astype(int)

    for xp, yp, a in zip(xs, ys, amps):
        x[yp, xp] = a
        
    return x

max_meep_amplitude = 1.0
conversion_norm = colors.Normalize(vmin=0, vmax=max_meep_amplitude*376.7, clip=True)
norm = colors.Normalize(vmin=0, vmax=max_meep_amplitude * 2, clip=True)

# %%
fig, axes = plt.subplots(1, 3, dpi=120)

sources, points, amplitudes = uniform_random_sources()

sim = mp.Simulation(cell_size=cell,
                    resolution=resolution,
                    geometry=geometry,
                    sources=sources,
                    boundary_layers=pml_layers,
                    force_complex_fields=True)

sim.init_sim()
sim.solve_cw()

arr = sim.get_array(component=mp.Ez)

x_img = get_x_img(arr, points, amplitudes)

with torch.no_grad(): 
    sources = torch.Tensor(x_img)[None, ..., None]
    pred = cpu_model(sources)

axes[0].imshow(x_img)
axes[1].imshow(pred.squeeze(0).permute(1, 2, 0), norm=norm)
axes[2].imshow(np.abs(arr), norm=norm)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 8.39233e-05 s
# Working in 2D dimensions.
# Computational cell is 14 x 14 x 0 with resolution 10
#      block, center = (0,0,0)
#           size (1e+20,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0276952 s
# -----------
# Meep: using complex fields.
# final residual = 8.16284e-09
# Finished solve_cw after 227 CG iters (~ 908 timesteps).
